# %% [markdown]
# # Homework 3
# Our goal is to collect the information from the *Michelin Guide* in order to help users to find a restaurant that reflects their unique tastes.
#
# - In order to do that, we firstly gather the data from the *Michelin Guide* [website](https://guide.michelin.com/en/it/restaurants).
#
# - Then, we build two types of search engines that allow users to retrieve restaurants according to their query.

# %% [markdown]
# # Collecting the data

# %% [markdown]
# ## Crawling

# %% [markdown]
# We gather all restaurant URLs from the guide and store them in a text file for further data processing.

# %%
import requests
from bs4 import BeautifulSoup

# Header for the request (optional, can help prevent the server from blocking the request)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# Open a file to write restaurant URLs
with open("michelin_restaurants_urls.txt", "w") as file:
    # Iterate through all pages (from 1 to 100)
    for page in range(1, 101):
        # Base URL with page number
        url = f"https://guide.michelin.com/en/it/restaurants/page/{page}"

        # Make the GET request
        response = requests.get(url, headers=headers)

        # Check if the request was successful
        if response.status_code == 200:
            # Create the BeautifulSoup object to parse the HTML content
            soup = BeautifulSoup(response.text, "html.parser")

            # Find all restaurant links
            restaurant_links = soup.find_all("a", class_="link")

            # Iterate over restaurant links and write URLs to the file
            for link in restaurant_links:
                href = link.get("href")
                if href and "/restaurant/" in href:
                    full_url = f"https://guide.michelin.com{href}"
                    file.write(full_url + "\n")
                    print(f"URL added: {full_url}")
        else:
            print(f"Error in request to page {page}: {response.status_code}")

# %% [markdown]
# We download the HTML content of Michelin restaurant pages concurrently, organizing each batch of 20 URLs into separate folders with the restaurant's name as the filename.

# %%
import requests
import os
from urllib.parse import urlparse
from concurrent.futures import ThreadPoolExecutor, as_completed
from time import sleep

# Header for the request (optional)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# Load URLs from the file
with open("michelin_restaurants_urls.txt", "r") as file:
    urls = [line.strip() for line in file.readlines()]

# Define the number of URLs per folder and max concurrent threads
url_per_folder = 20
max_threads = 5  # We can adjust the number of threads based on our network and system capacity

def download_html(url, folder_name):
    """Function to download HTML of a given URL and save it in the specified folder with the restaurant name."""
    try:
        # Extract restaurant name from the URL
        restaurant_name = urlparse(url).path.split('/')[-1]
        
        # Make the GET request
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            # Save the HTML content with the restaurant's name
            file_path = os.path.join(folder_name, f"{restaurant_name}.html")
            with open(file_path, "w", encoding="utf-8") as html_file:
                html_file.write(response.text)
            print(f"Saved: {file_path}")
        else:
            print(f"Error fetching {url}: {response.status_code}")
        sleep(0.1)  # Slight delay to avoid overwhelming the server

    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")

# Split URLs into groups of 20 and download concurrently
for i in range(0, len(urls), url_per_folder):
    folder_num = i // url_per_folder + 1
    folder_name = f"page_{folder_num}"
    
    # Create folder if it doesn't exist
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    
    # Get the next 20 URLs
    url_subset = urls[i:i + url_per_folder]

    # Use ThreadPoolExecutor to download concurrently
    with ThreadPoolExecutor(max_workers=max_threads) as executor:
        # Start a thread for each URL in the subset
        futures = [executor.submit(download_html, url, folder_name) for url in url_subset]
        
        # Wait for all threads in the subset to complete
        for future in as_completed(futures):
            future.result()  # Retrieve any exceptions if occurred
# Out:
# Saved: page_1\da-mo.html
# Saved: page_1\o-me-o-il-mare.html
# Saved: page_1\donevandro.html
# Saved: page_1\da-bob-cook-fish.html
# Saved: page_1\ape-vino-e-cucina.html
# Saved: page_1\charleston.html
# Saved: page_1\sa-domu-sarda.html
# Saved: page_1\alessandro-feo.html
# Saved: page_1\il-tirabuscio262517.html
# Saved: page_1\la-buca130947.html
# Saved: page_1\il-ristorante-alain-ducasse-napoli.html
# Saved: page_1\dama-1213583.html
# Saved: page_1\palazzo-utini.html
# Saved: page_1\etra.html
# Saved: page_1\soul-fish.html
# Saved: page_1\la-trattoria-enrico-bartolini.html
# Saved: page_1\loro.html
# Saved: page_1\20tre.html
# Saved: page_1\menage.html
# Saved: page_1\procaccini.html
# Saved: page_2\metodo-1213628.html
# Saved: page_2\gimmy-s.html
# Saved: page_2\osteria-dell-accademia.html
# Saved: page_2\fratelli-bruzzone.html
# Saved: page_2\serrae-villa-fiesole.html
# Saved: page_2\locanda-perbellini-ai-beati.html
# Saved: page_2\innesti.html
# Saved: page_2\salvo.html
# Saved: page_2\arnolfo.htmlSaved: page_2\osteria-del-teatro.html
#
# Saved: page_2\casin-del-gamba.html
# Saved: page_2\lupaia.html
# Saved: page_2\anticofurlo.html
# Saved: page_2\joca.html
# Saved: page_2\palais-royal-restaurant.html
# Saved: page_2\ostaria-pignatelli.html
# Saved: page_2\almondo-trattoria.html
# Saved: page_2\nobuya.html
# Saved: page_2\truth-restaurant.html
# Saved: page_2\altavilla.html
# Saved: page_3\abbruzzino-oltre.html
# Saved: page_3\abba.html
# Saved: page_3\ancora-1213776.html
# Saved: page_3\il-pirana.html
# Saved: page_3\kitchen-325766.html
# Saved: page_3\il-credenziere.html
# Saved: page_3\il-tartufo.html
# Saved: page_3\caruso-roof-garden.html
# Saved: page_3\quintilio.html
# Saved: page_3\hostaria-del-pavone.html
# Saved: page_3\trattoria-la-rosa.html
# Saved: page_3\frosch-restaurant.html
# Saved: page_3\amo-bistrot.html
# Saved: page_3\carusu.html
# Saved: page_3\exe-restaurant.html
# Saved: page_3\evo-ristorante.html
# Saved: page_3\san-baylon.html
# Saved: page_3\locanda-toscano-1198455.html
# Saved: page_3\l%E2%80%99alchimia.html
# Saved: page_3\io-e-luna.html
# Saved: page_4\bistrot-64.html
# Saved: page_4\forte-del-48.html
# Saved: page_4\bar-a-fromage.html
# Saved: page_4\il-giurista.html
# Saved: page_4\da-cesare.html
# Saved: page_4\lazaroun.html
# Saved: page_4\degusteria-italiana.html
# Saved: page_4\casa-perbellini.html
# Saved: page_4\cavallino.html
# Saved: page_4\la-villa139895.html
# Saved: page_4\antica-trattoria-gianna.html
# Saved: page_4\il-giardino-del-gusto.html
# Saved: page_4\derby-grill.html
# Saved: page_4\duomo160079.html
# Saved: page_4\oberraindlhof.html
# Saved: page_4\taverna-rovita.html
# Saved: page_4\foresta.html
# Saved: page_4\vitello-d-oro.html
# Saved: page_4\del-fagioli.html
# Saved: page_4\fracia.html
# Saved: page_5\es-cantina-ristorante.html
# Saved: page_5\san-giorgio562345.html
# Saved: page_5\mangiare-bere-uomo-donna.html
# Saved: page_5\abbruzzino.html
# Saved: page_5\il-gusto-di-xinge.html
# Saved: page_5\farmacia-dei-sani.html
# Saved: page_5\chicco-di-grano.html
# Saved: page_5\le-tre-colombe.html
# Saved: page_5\clemente.html
# Saved: page_5\dalla-rosa-alda.html
# Saved: page_5\nida.html
# Saved: page_5\la-passion.html
# Saved: page_5\caffe-bertaina-osteria.html
# Saved: page_5\dalla-gioconda.html
# Saved: page_5\locanda-lo-scopiccio.html
# Saved: page_5\brezza-fish-and-chill.html
# Saved: page_5\gallo-nero-1203031.html
# Saved: page_5\cannavacciuolo-le-cattedrali-asti.html
# Saved: page_5\vert-osteria-contemporanea.html
# Saved: page_5\lalibera.html
# Saved: page_6\attico-sul-mare.htmlSaved: page_6\hostaria-viola.html
#
# Saved: page_6\arca.html
# Saved: page_6\pascucci-al-porticciolo.html
# Saved: page_6\all-ombra-del-gabbiano.html
# Saved: page_6\alle-ciaspole.html
# Saved: page_6\il-saturnino.html
# Saved: page_6\vez.html
# Saved: page_6\zur-rose.html
# Saved: page_6\n-uovo-vino-e-cucina.html
# Saved: page_6\su-murruai.html
# Saved: page_6\agriturismo-ferdy.html
# Saved: page_6\il-mirto.html
# Saved: page_6\177-toledo.html
# Saved: page_6\artifex.html
# Saved: page_6\locanda-dei-narcisi.html
# Saved: page_6\cile-s.html
# Saved: page_6\votavota.html
# Saved: page_6\quattro-gigli.html
# Saved: page_6\hosteria-la-cave-cantu.html
# Saved: page_7\alla-lanterna.html
# Saved: page_7\soltojo.html
# Saved: page_7\retrogusto.html
# Saved: page_7\casa-coppelle.html
# Saved: page_7\la-ciau-del-tornavento.html
# Saved: page_7\corte-matilde.html
# Saved: page_7\johannes-stube.html
# Saved: page_7\da-severino-il-vecchio-di-luciano.html
# Saved: page_7\la-veranda141701.html
# Saved: page_7\trattoria-antichi-sapori.html
# Saved: page_7\walser-schtuba.htmlSaved: page_7\cip-s-club.html
#
# Saved: page_7\tuorlo-1198461.html
# Saved: page_7\harry-s-piccolo.html
# Saved: page_7\amo.html
# Saved: page_7\corte-federiciana.html
# Saved: page_7\old-friend.html
# Saved: page_7\le-beccherie.html
# Saved: page_7\luca-s-by-paulo-airaudo.html
# Saved: page_7\alla-locanda.html
# Saved: page_8\coltivare.html
# Saved: page_8\salegrosso.html
# Saved: page_8\da-gelsomina.html
# Saved: page_8\cestello-ristoclub.html
# Saved: page_8\trattoria-da-palmerino.html
# Saved: page_8\il-cortiletto.html
# Saved: page_8\sabir.html
# Saved: page_8\vineria-derthona.html
# Saved: page_8\l-officina.html
# Saved: page_8\wine-dine.html
# Saved: page_8\al-sorriso.html
# Saved: page_8\ai-torchi.html
# Saved: page_8\il-papavero.html
# Saved: page_8\colline-emiliane.html
# Saved: page_8\extra.html
# Saved: page_8\kiste.html
# Saved: page_8\trattoria-via-vai.html
# Saved: page_8\locanda-san-lorenzo.html
# Saved: page_8\zash.html
# Saved: page_8\osteria-del-trentino-da-marco.html
# Saved: page_9\cavallini.html
# Saved: page_9\lucenti.html
# Saved: page_9\l-ottava-nota.html
# Saved: page_9\mamma-rosa.html
# Saved: page_9\osteria-del-benedet.html
# Saved: page_9\gibas.html
# Saved: page_9\antiche-mura.html
# Saved: page_9\il-faggio.html
# Saved: page_9\trattoria-da-marino.html
# Saved: page_9\balzi-rossi.html
# Saved: page_9\aurora546380.html
# Saved: page_9\del-cambio.html
# Saved: page_9\scannabue-caffe-restaurant.html
# Saved: page_9\osteria-dei-mazzeri.html
# Saved: page_9\primo-restaurant.html
# Saved: page_9\bluh-furore.html
# Saved: page_9\camiano-piccolo.html
# Saved: page_9\l-armadillo.html
# Saved: page_9\la-fortuna.html
# Saved: page_9\pepenero-1198456.html
# Saved: page_10\locanda-delle-tre-chiavi.html
# Saved: page_10\il-ristorante-niko-romito-1209165.html
# Saved: page_10\quintogusto.html
# Saved: page_10\luminist-cafe-bistrot.html
# Saved: page_10\musciora.html
# Saved: page_10\bacaro-il-gusto.html
# Saved: page_10\osteria-mercato.html
# Saved: page_10\castello-di-fighine.html
# Saved: page_10\casa-rispoli.html
# Saved: page_10\osteria-le-panzanelle.html
# Saved: page_10\l-arcangelo.html
# Saved: page_10\torre-del-saracino.html
# Saved: page_10\eea.html
# Saved: page_10\verbano.html
# Saved: page_10\raieu.html
# Saved: page_10\la-tavola.html
# Saved: page_10\il-luogo-di-aimo-e-nadia.html
# Saved: page_10\la-brughiera.html
# Saved: page_10\dolada.html
# Saved: page_10\gasthofstube-stafler.html
# Saved: page_11\da-nonna-sceppa.html
# Saved: page_11\buriani-dal-1967.html
# Saved: page_11\tantris.html
# Saved: page_11\enoteca-al-parlamento-achilli.html
# Saved: page_11\franco-mare.html
# Saved: page_11\buca-di-sant-antonio.html
# Saved: page_11\antica-osteria-la-rampina.html
# Saved: page_11\i-ciocio-osteria-di-suvereto.html
# Saved: page_11\la-magnolia.html
# Saved: page_11\osteria-vecchio-borgo.html
# Saved: page_11\ai-mercanti.html
# Saved: page_11\4-ciance.html
# Saved: page_11\osteria-da-afro.html
# Saved: page_11\andreina.html
# Saved: page_11\da-gerry.html
# Saved: page_11\l-osteria-h20.html
# Saved: page_11\le-case-della-saracca.html
# Saved: page_11\cavour.html
# Saved: page_11\antica-osteria-magenes.html
# Saved: page_11\osteria-il-bagatto.html
# Saved: page_12\villetta-annessa.html
# Saved: page_12\la-rosina.html
# Saved: page_12\laite.html
# Saved: page_12\alle-corone.html
# Saved: page_12\la-fossa-del-grano.html
# Saved: page_12\le-calandre.html
# Saved: page_12\fiorentino-e-locanda-del-giglio.html
# Saved: page_12\la-barca.html
# Saved: page_12\casa-format.html
# Saved: page_12\50-kalo.html
# Saved: page_12\miculan.html
# Saved: page_12\il-sole-di-ranco.html
# Saved: page_12\menzaghi.html
# Saved: page_12\hostaria-del-teatro.html
# Saved: page_12\locanda-4-cuochi.html
# Saved: page_12\giglio.html
# Saved: page_12\foresta162722.html
# Saved: page_12\castello260046.html
# Saved: page_12\angelo-sabatelli.html
# Saved: page_12\enrico-bartolini-al-mudec.html
# Saved: page_13\malga-roncac.html
# Saved: page_13\morelli.html
# Saved: page_13\apollinare.html
# Saved: page_13\salvo-cacciatori.html
# Saved: page_13\3-noci-da-camillo.html
# Saved: page_13\ansitz-steinbock.html
# Saved: page_13\la-pajara.html
# Saved: page_13\il-pievano.html
# Saved: page_13\olona-da-venanzio-dal-1922.html
# Saved: page_13\osteria-dell-arborina.html
# Saved: page_13\al-palazzo.html
# Saved: page_13\j-contemporary-japanese-restaurant.html
# Saved: page_13\un-posto-a-milano-cascina-cuccagna.html
# Saved: page_13\la-locanda-del-borgo.html
# Saved: page_13\lo-scudiero.html
# Saved: page_13\s-andira.html
# Saved: page_13\la-tradizione-cucina-casalinga.html
# Saved: page_13\osteria-arbustico.html
# Saved: page_13\tre-olivi.html
# Saved: page_13\al-volt.html
# Saved: page_14\st-george-by-heinz-beck.html
# Saved: page_14\san-martino.html
# Saved: page_14\trequarti.html
# Saved: page_14\nni-lausta.html
# Saved: page_14\il-buco.html
# Saved: page_14\antica-osteria-il-monte-rosso.html
# Saved: page_14\il-convito-di-curina.html
# Saved: page_14\osteria-l-orciaia.html
# Saved: page_14\osteria-de-borg.html
# Saved: page_14\terrazza-bosquet.html
# Saved: page_14\hostaria-di-bacco.html
# Saved: page_14\posta151748.html
# Saved: page_14\daniel417950.html
# Saved: page_14\locanda-radici.html
# Saved: page_14\onda-blu.html
# Saved: page_14\da-nadia.html
# Saved: page_14\osteria-del-borgo352717.html
# Saved: page_14\ilario-vinciguerra.html
# Saved: page_14\agli-amici.html
# Saved: page_14\il-santo-bevitore.html
# Saved: page_15\moscatello-muliner.html
# Saved: page_15\me-restaurant.html
# Saved: page_15\al-cavallino-bianco.html
# Saved: page_15\del-belbo-da-bardon.html
# Saved: page_15\la-grotta-dal-1918.html
# Saved: page_15\l-oste-e-il-sacrestano.html
# Saved: page_15\el-filo.html
# Saved: page_15\papaveri-e-papere.html
# Saved: page_15\trattoria-losanna.html
# Saved: page_15\vespasia.html
# Saved: page_15\da-giacomo145911.html
# Saved: page_15\trippi.html
# Saved: page_15\regina-lucia.html
# Saved: page_15\la-locanda-di-piero.html
# Saved: page_15\il-galeone.html
# Saved: page_15\casa-del-vino-della-vallagarina.html
# Saved: page_15\filippino.html
# Saved: page_15\atelier161790.html
# Saved: page_15\entra.html
# Saved: page_15\marcelin.html
# Saved: page_16\viva-il-bistrot.html
# Saved: page_16\osteria-didu-1201493.html
# Saved: page_16\ca-del-moro.html
# Saved: page_16\la-torre141903.html
# Saved: page_16\angiolina.html
# Saved: page_16\i-due-buoi-1198450.html
# Saved: page_16\bites.html
# Saved: page_16\il-fico-trentacareghe.html
# Saved: page_16\il-fenicottero-rosa-gourmet.html
# Saved: page_16\l-uva-e-il-malto.html
# Saved: page_16\le-rune.html
# Saved: page_16\i-banchi.html
# Saved: page_16\maso-burba.html
# Saved: page_16\la-taverna-del-leone.html
# Saved: page_16\osteria-la-fontanina.html
# Saved: page_16\li-lioni.html
# Saved: page_16\la-cialoma.html
# Saved: page_16\le-baccanti.html
# Saved: page_16\la-sosta-di-ottone-iii.html
# Saved: page_16\controcorrente518148.html
# Saved: page_17\osteria-numero-2.htmlSaved: page_17\osteria-della-chiocciola.html
#
# Saved: page_17\al-bagatto.html
# Saved: page_17\menarosti.html
# Saved: page_17\oberlechner.html
# Saved: page_17\zur-blauen-traube.html
# Saved: page_17\bolle.html
# Saved: page_17\contrasto.html
# Saved: page_17\futura.html
# Saved: page_17\portanova.html
# Saved: page_17\saur.htmlSaved: page_17\al-cuoco-di-bordo.html
#
# Saved: page_17\osteria-la-solita-zuppa.html
# Saved: page_17\valli-di-lanzo.html
# Saved: page_17\uliassi.html
# Saved: page_17\le-colonne151641.html
# Saved: page_17\locanda-don-serafino.html
# Saved: page_17\nives.html
# Saved: page_17\ratana.html
# Saved: page_17\osteria-zanchetti.html
# Saved: page_18\locanda-mammi.html
# Saved: page_18\soho-restaurant-fish-work.html
# Saved: page_18\tilia.html
# Saved: page_18\al-dragone.html
# Saved: page_18\scrigno-del-duomo.html
# Saved: page_18\l-osteria-dell-orologio.html
# Saved: page_18\li-jalantuumene.html
# Saved: page_18\osteria-vecchia-noce.html
# Saved: page_18\sala-dei-grappoli.html
# Saved: page_18\di-martino-sea-front-pasta-bar.html
# Saved: page_18\bel-ami.html
# Saved: page_18\alpenrose.html
# Saved: page_18\do-leoni.html
# Saved: page_18\il-molo-430027.html
# Saved: page_18\guido361561.html
# Saved: page_18\prezioso.html
# Saved: page_18\trattoria-vecchia-sorni.html
# Saved: page_18\alessandro-mecca-al-castello-di-grinzane-cavour.html
# Saved: page_18\albergaccio-di-castellina.html
# Saved: page_18\borgo-san-jacopo.html
# Saved: page_19\la-corte.html
# Saved: page_19\la-capuccina.html
# Saved: page_19\mesadoria.html
# Saved: page_19\c-ucina.html
# Saved: page_19\casamare.html
# Saved: page_19\il-tiglio.html
# Saved: page_19\due-camini.html
# Saved: page_19\sogno.html
# Saved: page_19\dina.html
# Saved: page_19\koine.html
# Saved: page_19\trattoria-al-pompiere.html
# Saved: page_19\villa-de-winckels.html
# Saved: page_19\veritas.html
# Saved: page_19\trattoria-ai-due-platani.html
# Saved: page_19\beccaccino.html
# Saved: page_19\antico-albergo.html
# Saved: page_19\dodici-fontane.html
# Saved: page_19\la-rei-natura-by-michelangelo-mammoliti.html
# Saved: page_19\tana-de-l-ors.html
# Saved: page_19\terrazza-danieli.html
# Saved: page_20\shalai.html
# Saved: page_20\camana-veglia.html
# Saved: page_20\il-ridotto.html
# Saved: page_20\dell-alba.html
# Saved: page_20\la-cucina-di-donna-carmela.html
# Saved: page_20\trattoria-della-posta.html
# Saved: page_20\coppola-rossa.html
# Saved: page_20\il-calandrino.html
# Saved: page_20\italia.html
# Saved: page_20\da-manuela.html
# Saved: page_20\hostaria-alla-tavernetta.html
# Saved: page_20\trattoria-petito.html
# Saved: page_20\federico-ii.html
# Saved: page_20\il-fagiano.html
# Saved: page_20\la-braja.html
# Saved: page_20\bros.html
# Saved: page_20\il-cantinone-e-sport-hotel-alpina.html
# Saved: page_20\il-tiglio-di-piazza-da-nilo.html
# Saved: page_20\patauner.html
# Saved: page_20\quartopiano-suite-restaurant.html
# Saved: page_21\da-politano.html
# Saved: page_21\scaraboci.html
# Saved: page_21\cacciani.html
# Saved: page_21\chalet-pra-delle-nasse-da-anita.html
# Saved: page_21\antica-osteria-del-ponte.html
# Saved: page_21\osteria-dal-moro.html
# Saved: page_21\sichelburg.html
# Saved: page_21\l-argine-a-venco.html
# Saved: page_21\maeba-restaurant.html
# Saved: page_21\la-terrazza.html
# Saved: page_21\antica-pesa.htmlSaved: page_21\il-verso-del-ghiottone.html
#
# Saved: page_21\osteria-dei-vespri.html
# Saved: page_21\trattoria-del-nuovo-macello.html
# Saved: page_21\riva.html
# Saved: page_21\san-michele.html
# Saved: page_21\romano.html
# Saved: page_21\capriccio.html
# Saved: page_21\osteria-veglio.html
# Saved: page_21\antica-trattoria-del-gallo.html
# Saved: page_22\osteria-madonnetta.html
# Saved: page_22\buatta-cucina-popolana.html
# Saved: page_22\il-cappero.html
# Saved: page_22\l-angolino-da-filippo.html
# Saved: page_22\da-michele.html
# Saved: page_22\la-maison-delfino.html
# Saved: page_22\doppio-gusto.html
# Saved: page_22\aquariva.html
# Saved: page_22\pierre-alexis-1877.html
# Saved: page_22\da-gigetto.html
# Saved: page_22\fana-ladina.html
# Saved: page_22\antica-trattoria-cattivelli.html
# Saved: page_22\la-tana-gourmet.html
# Saved: page_22\sissi.html
# Saved: page_22\l-accanto.html
# Saved: page_22\all-olivo.html
# Saved: page_22\l-osteria-della-corte.html
# Saved: page_22\alex.html
# Saved: page_22\il-funghetto.html
# Saved: page_22\antico-ristorante-forassiepi.html
# Saved: page_23\ca-matilde.html
# Saved: page_23\ippogrifo.html
# Saved: page_23\da-andrea.html
# Saved: page_23\chichibio.html
# Saved: page_23\contesto-alimentare.html
# Saved: page_23\enoteca-san-nicola.html
# Saved: page_23\ai-gondolieri.html
# Saved: page_23\santa-teresa.html
# Saved: page_23\la-tavola-di-guido.html
# Saved: page_23\svevia.html
# Saved: page_23\andrea-sapori-montani.html
# Saved: page_23\la-veranda-162636.html
# Saved: page_23\il-cascinalenuovo.html
# Saved: page_23\burro-alici.html
# Saved: page_23\da-oscar.html
# Saved: page_23\da-fausto478177.html
# Saved: page_23\al-grop.html
# Saved: page_23\roma.html
# Saved: page_23\canapone.html
# Saved: page_23\osteria-del-mirasole.html
# Saved: page_24\don-camillo.html
# Saved: page_24\il-sanlorenzo.html
# Saved: page_24\il-ciabot.html
# Saved: page_24\l-oste-dispensa.html
# Saved: page_24\el-primero.html
# Saved: page_24\21-9.html
# Saved: page_24\dim-sum.html
# Saved: page_24\zappatori.html
# Saved: page_24\hostaria-uva-rara.html
# Saved: page_24\il-patio.html
# Saved: page_24\la-ferrata.html
# Saved: page_24\il-tufo-allegro.html
# Saved: page_24\luna-rossa.html
# Saved: page_24\sa-musciara.html
# Saved: page_24\durnwald.html
# Saved: page_24\tanzer.html
# Saved: page_24\la-peniche.html
# Saved: page_24\bove-s.html
# Saved: page_24\antica-osteria-nonna-rosa.html
# Saved: page_24\il-cipresso-da-cioni.html
# Saved: page_25\la-trota.html
# Saved: page_25\al-piave.html
# Saved: page_25\bistrot-donatella.html
# Saved: page_25\qb-duepuntozero.html
# Saved: page_25\joia.html
# Saved: page_25\la-masseria.html
# Saved: page_25\taverna-dei-caldora.html
# Saved: page_25\l-oste-scuro.html
# Saved: page_25\winter-garden-florence.html
# Saved: page_25\innocenti-evasioni.html
# Saved: page_25\acquerello197794.html
# Saved: page_25\kandoo-nippon.html
# Saved: page_25\la-quartina.html
# Saved: page_25\aroma.html
# Saved: page_25\rosita.html
# Saved: page_25\locanda-800.html
# Saved: page_25\da-o-vittorio.html
# Saved: page_25\filippo.html
# Saved: page_25\grantosco.html
# Saved: page_25\bislakko.html
# Saved: page_26\il-michelaccio.html
# Saved: page_26\saporium-firenze.html
# Saved: page_26\trattoria-leoni.html
# Saved: page_26\al-vedel.html
# Saved: page_26\13-comuni.html
# Saved: page_26\u-p-e-p-i-d-d-e.html
# Saved: page_26\dolomieu.html
# Saved: page_26\il-sale.html
# Saved: page_26\taverna-il-grappolo-blu.html
# Saved: page_26\la-serra.html
# Saved: page_26\al-palazzon.html
# Saved: page_26\la-pineta148217.html
# Saved: page_26\re-mauri.html
# Saved: page_26\28-posti.html
# Saved: page_26\serendib.html
# Saved: page_26\contraste.html
# Saved: page_26\ingalera.html
# Saved: page_26\vitantonio-lombardo.html
# Saved: page_26\stella.html
# Saved: page_26\cibreo.html
# Saved: page_27\pomiroeu.html
# Saved: page_27\perbacco530053.html
# Saved: page_27\parma-rotta.html
# Saved: page_27\imperialino.html
# Saved: page_27\osteria-fernanda.html
# Saved: page_27\la-refezione.html
# Saved: page_27\podere-san-faustino.html
# Saved: page_27\forentum.html
# Saved: page_27\spin-ristorante-enoteca-sola.html
# Saved: page_27\trattoria-lanzagallo.html
# Saved: page_27\caino.html
# Saved: page_27\marina-del-nettuno.html
# Saved: page_27\aimo-e-nadia-bistro.html
# Saved: page_27\la-kuccagna.html
# Saved: page_27\cielo.html
# Saved: page_27\terrazza-costantino.html
# Saved: page_27\locanda-perbellini.html
# Saved: page_27\osteria-enoteca-gambrinus.html
# Saved: page_27\i-sette-consoli.html
# Saved: page_27\hanswirt.html
# Saved: page_28\sarri.html
# Saved: page_28\al-covo.html
# Saved: page_28\capo-santa-chiara.html
# Saved: page_28\signum.html
# Saved: page_28\ai-cadelach.html
# Saved: page_28\seta-by-antonio-guida.html
# Saved: page_28\trattoria-del-pesce.html
# Saved: page_28\osteria-la-fefa.html
# Saved: page_28\miranda148125.html
# Saved: page_28\manuelina.html
# Saved: page_28\sud.html
# Saved: page_28\osteria-la-lanterna.html
# Saved: page_28\bagatto.html
# Saved: page_28\la-madia.html
# Saved: page_28\oscar.html
# Saved: page_28\bacucco-d-oro.html
# Saved: page_28\la-perla-del-mare.html
# Saved: page_28\crocifisso.html
# Saved: page_28\acanto69200.html
# Saved: page_28\osteria-frangipane.html
# Saved: page_29\la-conchiglia-d-oro.html
# Saved: page_29\vairo-del-volturno.html
# Saved: page_29\baia-del-silenzio.html
# Saved: page_29\the-cesar.html
# Saved: page_29\le-grenier.html
# Saved: page_29\mondschein-food-experience.html
# Saved: page_29\rio-bistrot.html
# Saved: page_29\nostrano.html
# Saved: page_29\osteria-la-sangiovesa.html
# Saved: page_29\le-trabe.html
# Saved: page_29\alla-corte-lombarda.html
# Saved: page_29\i-savi.html
# Saved: page_29\ora-d-aria.html
# Saved: page_29\enoteca-pinchiorri.html
# Saved: page_29\locanda-del-feudo.html
# Saved: page_29\la-capinera.html
# Saved: page_29\dama-restaurant.html
# Saved: page_29\aede-dining-wines.html
# Saved: page_29\osteria-a-le-due-spade-1198464.html
# Saved: page_29\iacobucci.html
# Saved: page_30\madonnina-del-pescatore.html
# Saved: page_30\atelier-moessmer-norbert-niederkofler.html
# Saved: page_30\carignano.html
# Saved: page_30\benso.html
# Saved: page_30\poldo-e-gianna-osteria.html
# Saved: page_30\antica-trattoria-la-toppa.html
# Saved: page_30\l-osteria-di-santa-marina.html
# Saved: page_30\ponte-pietra.html
# Saved: page_30\dopolavoro.html
# Saved: page_30\la-corte144371.html
# Saved: page_30\da-vincenzo.html
# Saved: page_30\gourmetstube-einhorn.html
# Saved: page_30\la-notizia.html
# Saved: page_30\dalla-libera.html
# Saved: page_30\osaka.html
# Saved: page_30\apollonia.html
# Saved: page_30\al-segnavento.html
# Saved: page_30\san-lorenzo.html
# Saved: page_30\la-torre166500.html
# Saved: page_30\da-annetta.html
# Saved: page_31\la-palomba.html
# Saved: page_31\l-acino.html
# Saved: page_31\anna-stuben.html
# Saved: page_31\relais-blu.html
# Saved: page_31\moma.html
# Saved: page_31\saqua-by-il-frantoio.html
# Saved: page_31\lanterna-verde.html
# Saved: page_31\arva.html
# Saved: page_31\osteria-boccolicchio.html
# Saved: page_31\bistrot-quarantunododici.html
# Saved: page_31\ristorante-alpes-la-fuga.html
# Saved: page_31\zero-milano.html
# Saved: page_31\locanda-del-falco.html
# Saved: page_31\magorabin.html
# Saved: page_31\mater-terrae.html
# Saved: page_31\tosca435462.html
# Saved: page_31\condividere.html
# Saved: page_31\rosselli-77.html
# Saved: page_31\boivin.html
# Saved: page_31\la-leggenda-dei-frati.html
# Saved: page_32\stube-hermitage.html
# Saved: page_32\all-oro.html
# Saved: page_32\rovello-18.html
# Saved: page_32\il-ristorante-di-guido-da-costigliole.html
# Saved: page_32\krone.html
# Saved: page_32\taverna-degli-acaja.html
# Saved: page_32\controcorrente.html
# Saved: page_32\trattoria-al-passo.html
# Saved: page_32\buscone.html
# Saved: page_32\campo-del-drago.html
# Saved: page_32\osteria-del-36.html
# Saved: page_32\taberna-romani.html
# Saved: page_32\bistrot147741.html
# Saved: page_32\osteria-manzoni.html
# Saved: page_32\berton.html
# Saved: page_32\da-guido.html
# Saved: page_32\villa-maiella.html
# Saved: page_32\esplanade.html
# Saved: page_32\la-sponda.html
# Saved: page_32\la-valle.html
# Saved: page_33\antica-locanda-al-cervo-landgasthof-zum-hirschen.html
# Saved: page_33\la-coccinella.html
# Saved: page_33\lido-84.html
# Saved: page_33\oberwirt.html
# Saved: page_33\cucina-cereda.html
# Saved: page_33\le-lampare-al-fortino.html
# Saved: page_33\panevin.html
# Saved: page_33\braunwirt.html
# Saved: page_33\vintage-1997.html
# Saved: page_33\veneziano.html
# Saved: page_33\terme.html
# Saved: page_33\boccadoro.html
# Saved: page_33\locanda-margon.html
# Saved: page_33\bon-wei.html
# Saved: page_33\la-locanda-del-notaio.html
# Saved: page_33\lapprodo.html
# Saved: page_33\colonne.html
# Saved: page_33\mikele.html
# Saved: page_33\bacco-e-arianna.html
# Saved: page_33\kleine-flamme.html
# Saved: page_34\trattoria-da-paeto.html
# Saved: page_34\osteria-numero-sette.html
# Saved: page_34\la-chiocciola.html
# Saved: page_34\i-castagni.html
# Saved: page_34\al-bersagliere.html
# Saved: page_34\da-giovanni.html
# Saved: page_34\leonefelice.html
# Saved: page_34\darmagi.html
# Saved: page_34\president.html
# Saved: page_34\cracco.html
# Saved: page_34\l-a-gourmet-l-accademia.html
# Saved: page_34\il-sogno.html
# Saved: page_34\caffetteria-la-fugascina.html
# Saved: page_34\al-capitan-della-cittadella.html
# Saved: page_34\riso-amaro.html
# Saved: page_34\trattoria-alla-pergola.html
# Saved: page_34\alpenroyal-gourmet.html
# Saved: page_34\giorgio-e-flora.html
# Saved: page_34\trattoria-i-masenini.html
# Saved: page_34\hosteria-giusti.html
# Saved: page_35\tre-noghere.html
# Saved: page_35\schoneck.html
# Saved: page_35\zum-lowen.html
# Saved: page_35\quellenhof-gourmetstube-1897.html
# Saved: page_35\castel-fine-dining.html
# Saved: page_35\menegaldo.html
# Saved: page_35\marcandole.html
# Saved: page_35\gino-sorbillo.html
# Saved: page_35\al-fogher.html
# Saved: page_35\trattoria-di-coronate.html
# Saved: page_35\da-giannino-l-angolo-d-abruzzo.html
# Saved: page_35\gellius.html
# Saved: page_35\cannavacciuolo-bistrot.html
# Saved: page_35\muraglia-conchiglia-d-oro.html
# Saved: page_35\gratschwirt.html
# Saved: page_35\l-archivolto-osteria-nostrale.html
# Saved: page_35\abocar-due-cucine.html
# Saved: page_35\trita-pepe.html
# Saved: page_35\domenico-dal-1968.html
# Saved: page_35\la-pineta.html
# Saved: page_36\io-osteria-personale.html
# Saved: page_36\bistrot-de-venise.html
# Saved: page_36\la-campanara.html
# Saved: page_36\oro-restaurant.html
# Saved: page_36\indaco.html
# Saved: page_36\la-martinatica.html
# Saved: page_36\accursio.html
# Saved: page_36\hidalgo.html
# Saved: page_36\sadler.html
# Saved: page_36\la-brinca.html
# Saved: page_36\villa-giulia-al-terrazzo.htmlSaved: page_36\sa-mandra.html
#
# Saved: page_36\il-melograno155156.html
# Saved: page_36\umberto-a-mare.html
# Saved: page_36\rezzano-cucina-e-vino.html
# Saved: page_36\ca-vittoria.html
# Saved: page_36\da-gigi.html
# Saved: page_36\borgo-spoltino.html
# Saved: page_36\alla-laguna-vedova-raddi.html
# Saved: page_36\corte-visconti.html
# Saved: page_37\trattoria-glisenti.html
# Saved: page_37\la-filanda.html
# Saved: page_37\sapereta.html
# Saved: page_37\la-terrazza68963.html
# Saved: page_37\corte-sconta.html
# Saved: page_37\la-lumira.html
# Saved: page_37\enoteca-del-duca.html
# Saved: page_37\trattoria-ceriati.html
# Saved: page_37\la-cantinella154248.html
# Saved: page_37\due-pini.html
# Saved: page_37\iyo.html
# Saved: page_37\sedicesimo-secolo.html
# Saved: page_37\jose-restaurant-tenuta-villa-guerra.html
# Saved: page_37\vecchia-malcesine.html
# Saved: page_37\villa-arcadio.html
# Saved: page_37\zeb.html
# Saved: page_37\il-favri.html
# Saved: page_37\al-metro.html
# Saved: page_37\trattoria-alla-ruota.html
# Saved: page_37\cascina-vittoria.html
# Saved: page_38\i-tigli.html
# Saved: page_38\la-locanda-del-capitano.html
# Saved: page_38\tola-rasa.html
# Saved: page_38\il-trillo139594.html
# Saved: page_38\da-burde.html
# Saved: page_38\la-cantina-di-manuela69273.html
# Saved: page_38\del-turista-da-marchesi.html
# Saved: page_38\pacifico.html
# Saved: page_38\voltalacarta.html
# Saved: page_38\opera-02.html
# Saved: page_38\trattoria-bibe.html
# Saved: page_38\la-filanda258327.html
# Saved: page_38\da-noemi.html
# Saved: page_38\punta-lena.html
# Saved: page_38\il-liberty.html
# Saved: page_38\il-merlo.html
# Saved: page_38\le-antiche-sere.html
# Saved: page_38\battipalo.html
# Saved: page_38\il-capestrano.html
# Saved: page_38\meltemi.html
# Saved: page_39\trattoria-del-vicolo.html
# Saved: page_39\d-one-restaurant-diffuso.html
# Saved: page_39\osteria-piazzetta-cattedrale.html
# Saved: page_39\casa-d-angelo.html
# Saved: page_39\villa-crespi.html
# Saved: page_39\la-taverna-di-fra-fiusch.html
# Saved: page_39\il-convivio-troiani.html
# Saved: page_39\taverna-kus.html
# Saved: page_39\ba-asian-mood.html
# Saved: page_39\antica-osteria.html
# Saved: page_39\il-ristorante-niko-romito.html
# Saved: page_39\profumi-del-cous-cous.html
# Saved: page_39\orto.html
# Saved: page_39\da-nicolo.html
# Saved: page_39\amista-33.html
# Saved: page_39\lo-scalco-grasso.html
# Saved: page_39\la-cuccagna.html
# Saved: page_39\locanda-dei-salinari.html
# Saved: page_39\ca-apollonio-gourmet.html
# Saved: page_39\essenziale.html
# Saved: page_40\il-centro.html
# Saved: page_40\stella-d-italia.html
# Saved: page_40\la-braseria.html
# Saved: page_40\l-antico-giardino.html
# Saved: page_40\la-presef.html
# Saved: page_40\vecchio-porto.html
# Saved: page_40\de-gustibus-maurizio.html
# Saved: page_40\la-credenza.html
# Saved: page_40\botero.html
# Saved: page_40\baccanti.html
# Saved: page_40\lipadusa.html
# Saved: page_40\pierino-penati.html
# Saved: page_40\locanda-cacciatori.html
# Saved: page_40\le-miniere.html
# Saved: page_40\da-odino.html
# Saved: page_40\la-gritta.html
# Saved: page_40\osteria-della-villetta.html
# Saved: page_40\green-t.html
# Saved: page_40\al-paradiso.html
# Saved: page_40\da-flavio-e-fabrizio-al-teatro.html
# Saved: page_41\sibilla.html
# Saved: page_41\la-tortuga.html
# Saved: page_41\trattoria-cibreo-cibreino.html
# Saved: page_41\bracali.html
# Saved: page_41\la-chioccia-d-oro.html
# Saved: page_41\butterfly.html
# Saved: page_41\il-gallo-cedrone.html
# Saved: page_41\degusteria-del-gigante.html
# Saved: page_41\next2.html
# Saved: page_41\mildas.html
# Saved: page_41\la-fiaschetteria.html
# Saved: page_41\osteria-della-brughiera.html
# Saved: page_41\oasis-sapori-antichi.html
# Saved: page_41\balin-sestri-levante.html
# Saved: page_41\antonello-colonna-labico.html
# Saved: page_41\la-cascina-1899.html
# Saved: page_41\osteria-dalla-peppa.html
# Saved: page_41\corsaro-nero.html
# Saved: page_41\cantina-dei-cacciatori.html
# Saved: page_41\lo-stuzzichino.html
# Saved: page_42\venissa.html
# Saved: page_42\cavalluccio-marino.html
# Saved: page_42\crotto-valtellina.html
# Saved: page_42\nicolin.html
# Saved: page_42\atman.html
# Saved: page_42\tre-galline.html
# Saved: page_42\marco-martini-restaurant.html
# Saved: page_42\taverna-58.html
# Saved: page_42\fiorfiore.html
# Saved: page_42\osteria-1126.html
# Saved: page_42\casa-del-nonno-13.html
# Saved: page_42\cinzia-da-christian-e-manuel.html
# Saved: page_42\il-conte-matto.html
# Saved: page_42\villa-feltrinelli.html
# Saved: page_42\estro-vino-e-cucina.html
# Saved: page_42\duo-ristorante.html
# Saved: page_42\al-gatto-rosso.html
# Saved: page_42\florian-maison.html
# Saved: page_42\rifugio-fuciade.html
# Saved: page_42\suinsom.html
# Saved: page_43\cucina-bacilieri.html
# Saved: page_43\al-capriolo.html
# Saved: page_43\villa-aurora.html
# Saved: page_43\al-gatto-nero-da-ruggero.html
# Saved: page_43\la-meridiana.html
# Saved: page_43\sale-grosso.html
# Saved: page_43\casamatta.html
# Saved: page_43\satricvm.html
# Saved: page_43\la-fratanza.html
# Saved: page_43\bruxaboschi.html
# Saved: page_43\trattoria-da-fagiolino.html
# Saved: page_43\cocchi.html
# Saved: page_43\malga-panna.html
# Saved: page_43\parizzi.html
# Saved: page_43\bistrot.html
# Saved: page_43\antica-locanda-del-villoresi.html
# Saved: page_43\per-me-giulio-terrinoni.html
# Saved: page_43\zass.html
# Saved: page_43\le-viole.html
# Saved: page_43\glass-hostaria.html
# Saved: page_44\romani.html
# Saved: page_44\il-basilisco.html
# Saved: page_44\cannavacciuolo-by-the-lake.html
# Saved: page_44\da-concettina-ai-tre-santi.html
# Saved: page_44\la-cucoma.html
# Saved: page_44\ma-ri-na.html
# Saved: page_44\franceschetta-58.html
# Saved: page_44\sa-corte.html
# Saved: page_44\teresa.html
# Saved: page_44\regio-patio.html
# Saved: page_44\osteria-verciani-il-mecenate-a-lucca.html
# Saved: page_44\1500.html
# Saved: page_44\osteria-del-gua.html
# Saved: page_44\vino-buono.html
# Saved: page_44\finger-s-garden.html
# Saved: page_44\emilio.html
# Saved: page_44\cucina-da-omar.html
# Saved: page_44\belle-parti.html
# Saved: page_44\campiello.html
# Saved: page_44\l-acchiatura.html
# Saved: page_45\degli-angeli.html
# Saved: page_45\palazzo-petrucci.html
# Saved: page_45\il-pozzo.html
# Saved: page_45\trattoria-al-ponte138786.html
# Saved: page_45\trippa.html
# Saved: page_45\la-saletta.html
# Saved: page_45\a-spurcacciun-a.html
# Saved: page_45\l-800.html
# Saved: page_45\aquadulcis.html
# Saved: page_45\al-convento.html
# Saved: page_45\lux-lucis.html
# Saved: page_45\langosteria.html
# Saved: page_45\dongio.html
# Saved: page_45\la-bandiera.html
# Saved: page_45\antica-corte-pallavicina.html
# Saved: page_45\la-perla.html
# Saved: page_45\maxi.html
# Saved: page_45\anima-fine-dining.html
# Saved: page_45\il-pagliaccio.html
# Saved: page_45\don-alfonso-1890-151521.html
# Saved: page_46\vineria-modi.html
# Saved: page_46\marixx.html
# Saved: page_46\re-santi-e-leoni.html
# Saved: page_46\punto-g.html
# Saved: page_46\l-ambasciata.html
# Saved: page_46\locanda-nelli.htmlSaved: page_46\confusion.html
#
# Saved: page_46\i-giardini-dei-rodo.html
# Saved: page_46\nana-piccolo-bistro.html
# Saved: page_46\hosteria-grappolo-d-oro.html
# Saved: page_46\la-cucina-dei-frigoriferi-milanesi.html
# Saved: page_46\locanda-da-condo.html
# Saved: page_46\il-pellicano.html
# Saved: page_46\pipero.html
# Saved: page_46\osteria-borgo-ronche.html
# Saved: page_46\alla-pace.html
# Saved: page_46\osteria-il-principe-e-il-pirata.html
# Saved: page_46\locanda-del-sant-uffizio-enrico-bartolini.html
# Saved: page_46\osteria-bellavista.html
# Saved: page_46\da-nando.html
# Saved: page_47\armani.html
# Saved: page_47\ai-campi-di-marcello.html
# Saved: page_47\le-due-lanterne.html
# Saved: page_47\gong.html
# Saved: page_47\ruris.html
# Saved: page_47\al-cjasal.html
# Saved: page_47\taverna-dell-oca.html
# Saved: page_47\terrazza-fiorella.html
# Saved: page_47\al-tonno-di-corsa.html
# Saved: page_47\la-torre139632.html
# Saved: page_47\a-cuncuma.html
# Saved: page_47\soprattutto.html
# Saved: page_47\il-latini.html
# Saved: page_47\gina.html
# Saved: page_47\mos-1199050.html
# Saved: page_47\secondo-tempo.html
# Saved: page_47\osteria-billis.html
# Saved: page_47\motelombroso.html
# Saved: page_47\dav-mare.html
# Saved: page_47\mame-restaurant.html
# Saved: page_48\felix-lo-basso-home-restaurant.html
# Saved: page_48\locanda-marchesani.html
# Saved: page_48\l-acciuga-1190130.html
# Saved: page_48\aria-1206715.html
# Saved: page_48\santa-elisabetta.html
# Saved: page_48\quattro-passi.htmlSaved: page_48\lokanda-devetak.html
# Saved: page_48\specus.html
# Saved: page_48\locanda-la-raia.html
#
# Saved: page_48\rada.html
# Saved: page_48\cucine-nervi.html
# Saved: page_48\olio.html
# Saved: page_48\da-carla.html
# Saved: page_48\hosteria-toblino.html
# Saved: page_48\jamante.html
# Saved: page_48\gimmi-restaurant.html
# Saved: page_48\antiche-sere.html
# Saved: page_48\filo.html
# Saved: page_48\hydra.html
# Saved: page_48\dry-aged.html
# Saved: page_49\antica-trattoria-centro.html
# Saved: page_49\bottega-culinaria.html
# Saved: page_49\bebop.html
# Saved: page_49\forma.html
# Saved: page_49\ada.html
# Saved: page_49\radici-1190542.html
# Saved: page_49\augurio.html
# Saved: page_49\corbezzoli.html
# Saved: page_49\l-aria.html
# Saved: page_49\mec-restaurant.html
# Saved: page_49\antica-trattoria-giovanelli.html
# Saved: page_49\san-domenico-1204856.html
# Saved: page_49\luigi-lepore.html
# Saved: page_49\ipalici.html
# Saved: page_49\maso-palu.html
# Saved: page_49\modi.html
# Saved: page_49\gabbiano-3-0.html
# Saved: page_49\coxinendi.html
# Saved: page_49\opera-1184623.html
# Saved: page_49\autem.html
# Saved: page_50\agritur-el-mas.html
# Saved: page_50\l-insolita-trattoria-tre-soldi.html
# Saved: page_50\canova-by-sadler.html
# Saved: page_50\il-marin-eataly.html
# Saved: page_50\rear-restaurant.html
# Saved: page_50\il-sottomarino.html
# Saved: page_50\le-cicale-in-citta.html
# Saved: page_50\quel-fantastico-giovedi.html
# Saved: page_50\la-maison-de-filip.html
# Saved: page_50\casa-buono.html
# Saved: page_50\duo-1192304.html
# Saved: page_50\hazama.html
# Saved: page_50\il-marchese-osteria-mercato-liquori-1204539.html
# Saved: page_50\osteria-degli-assonica.html
# Saved: page_50\vite-1205287.html
# Saved: page_50\radici-osteria-contemporanea-1196408.html
# Saved: page_50\aprudia.html
# Saved: page_50\gioele.html
# Saved: page_50\rueda-gaucha.html
# Saved: page_50\antica-macelleria-cecchini-solociccia.html
# Saved: page_51\impronta-d-acqua.html
# Saved: page_51\brindo-by-orlando.html
# Saved: page_51\ceresio-7.html
# Saved: page_51\imago.html
# Saved: page_51\edelweiss.html
# Saved: page_51\porta-di-basso.html
# Saved: page_51\l-aia-dei-cappellani.html
# Saved: page_51\caffe-grande.html
# Saved: page_51\inkiostro.html
# Saved: page_51\antica-locanda-di-sesto.html
# Saved: page_51\tancredi.html
# Saved: page_51\caffe-dante-bistrot.html
# Saved: page_51\serendepico.html
# Saved: page_51\locanda-sensi.html
# Saved: page_51\dolce-stil-novo-alla-reggia.html
# Saved: page_51\gucci-osteria-da-massimo-bottura.html
# Saved: page_51\le-cedrare.html
# Saved: page_51\la-baita.html
# Saved: page_51\osteria-da-pietro.html
# Saved: page_51\osteria-storica-morelli.html
# Saved: page_52\wicky-s-wicuisine.html
# Saved: page_52\la-speranzina-restaurant-relais.html
# Saved: page_52\il-convito-della-venaria.html
# Saved: page_52\la-locanda-del-colonnello.html
# Saved: page_52\piazza-dei-mestieri.html
# Saved: page_52\cipasso-bistrot.html
# Saved: page_52\vecchia-lama.html
# Saved: page_52\osteria-alle-testiere.html
# Saved: page_52\dei-cantoni.html
# Saved: page_52\paolo-e-barbara.html
# Saved: page_52\osteria-dei-segreti.html
# Saved: page_52\la-bucaccia.html
# Saved: page_52\bacchus.html
# Saved: page_52\maso-runch-hof.html
# Saved: page_52\osteria-di-passignano.html
# Saved: page_52\dalie-e-fagioli.html
# Saved: page_52\antica-osteria-moirago.html
# Saved: page_52\horto-1204821.html
# Saved: page_52\lerchner-s-in-runggen.html
# Saved: page_52\impronta-1202752.html
# Saved: page_53\cuculia.html
# Saved: page_53\alto.html
# Saved: page_53\alpinn.html
# Saved: page_53\locanda-viola.html
# Saved: page_53\i-portici.html
# Saved: page_53\duo-1196308.html
# Saved: page_53\la-foresteria.html
# Saved: page_53\contaminazioni-restaurant.html
# Saved: page_53\senso-alfio-ghezzi-lake-garda.html
# Saved: page_53\al-petes.html
# Saved: page_53\ca-del-profeta.html
# Saved: page_53\kirchsteiger.html
# Saved: page_53\i-fame.html
# Saved: page_53\da-orlando.html
# Saved: page_53\la-dispensa-di-armatore.html
# Saved: page_53\da-ercole.html
# Saved: page_53\la-rosa-dei-venti.html
# Saved: page_53\i-due-cippi-da-michele.html
# Saved: page_53\da-giocondo.html
# Saved: page_53\ego.html
# Saved: page_54\le-logge-del-vignola.html
# Saved: page_54\piacentino.html
# Saved: page_54\nuova-roma.html
# Saved: page_54\taverna-dello-spuntino.html
# Saved: page_54\l-ancora-della-tortuga.html
# Saved: page_54\tubladel.html
# Saved: page_54\la-corniola.html
# Saved: page_54\osteria-del-gallo-e-della-volpe.html
# Saved: page_54\lazzaro-1915.html
# Saved: page_54\terre-alte.html
# Saved: page_54\antico-morer.html
# Saved: page_54\ca-mia.html
# Saved: page_54\impero.html
# Saved: page_54\osteria-altran.html
# Saved: page_54\dulchemente.html
# Saved: page_54\silene.html
# Saved: page_54\piccolo-lord.html
# Saved: page_54\osteria-del-borro.html
# Saved: page_54\villa-fiordaliso.html
# Saved: page_54\osteria-antico-brolo.html
# Saved: page_55\capriccio-1200379.html
# Saved: page_55\al-vecchio-convento.html
# Saved: page_55\sora-maria-e-arcangelo.html
# Saved: page_55\il-casolare-dei-segreti.html
# Saved: page_55\la-locanda-del-falco.html
# Saved: page_55\le-cupole.html
# Saved: page_55\tamo.html
# Saved: page_55\filia-ristorante.html
# Saved: page_55\san-domenico.html
# Saved: page_55\osteria-acquarol.html
# Saved: page_55\gune-san-frediano.html
# Saved: page_55\milano.html
# Saved: page_55\mar-divino.html
# Saved: page_55\lorelei.html
# Saved: page_55\kosmo-taste-the-mountain.html
# Saved: page_55\pulejo.html
# Saved: page_55\osteria-platzegg.html
# Saved: page_55\gainn.html
# Saved: page_55\cosmo-restaurant.html
# Saved: page_55\vitique.html
# Saved: page_56\la-peca.html
# Saved: page_56\il-cavallino.html
# Saved: page_56\osteria-del-tasso.html
# Saved: page_56\cannavacciuolo-countryside.html
# Saved: page_56\guallina.html
# Saved: page_56\acqua-pazza-1192022.html
# Saved: page_56\marotta.html
# Saved: page_56\taverna-del-capitano.html
# Saved: page_56\la-madernassa.html
# Saved: page_56\vivace.html
# Saved: page_56\mogano.html
# Saved: page_56\vecio-macello.html
# Saved: page_56\zaghara-restaurant.html
# Saved: page_56\salotto-sul-mare.html
# Saved: page_56\materia-prima.html
# Saved: page_56\scatto.html
# Saved: page_56\antica-osteria-il-ronchettino.html
# Saved: page_56\ichikawa.html
# Saved: page_56\le-cementine.html
# Saved: page_56\le-macine.html
# Saved: page_57\delicato.html
# Saved: page_57\la-societa-milano.html
# Saved: page_57\radici-1077246.html
# Saved: page_57\campocori.html
# Saved: page_57\casa-vicina.html
# Saved: page_57\moi.html
# Saved: page_57\nugolo.html
# Saved: page_57\osteria-ricanatti.html
# Saved: page_57\terramadre.html
# Saved: page_57\la-coldana.html
# Saved: page_57\altatto-bistrot.html
# Saved: page_57\altrimenti.html
# Saved: page_57\peter-brunel-ristorante-gourmet.html
# Saved: page_57\fre.html
# Saved: page_57\la-torre153575.html
# Saved: page_57\trattoria-della-fortuna.html
# Saved: page_57\comi-107.html
# Saved: page_57\fe.html
# Saved: page_57\cucina-rambaldi.html
# Saved: page_57\moebius-sperimentale.html
# Saved: page_58\remo-villa-cariolato.html
# Saved: page_58\carlo-e-camillo.html
# Saved: page_58\ps-ristorante-1192505.html
# Saved: page_58\osteria-bakare.html
# Saved: page_58\madama-piola.html
# Saved: page_58\ronchi-ro.html
# Saved: page_58\il-visibilio.html
# Saved: page_58\spinechile.html
# Saved: page_58\il-vescovado.html
# Saved: page_58\diana-s-place.html
# Saved: page_58\the-cook.html
# Saved: page_58\i-tri-siochett.html
# Saved: page_58\locanda-di-orta.html
# Saved: page_58\enotavola.html
# Saved: page_58\il-presidente.html
# Saved: page_58\osteria-della-tana.html
# Saved: page_58\seta-sushi-restaurant.html
# Saved: page_58\trattoria-da-me.html
# Saved: page_58\la-chandelle1154957.html
# Saved: page_58\balice.html
# Saved: page_59\l-osti.html
# Saved: page_59\cortile-arabo.html
# Saved: page_59\palazzo-petrucci-pizzeria.html
# Saved: page_59\la-locanda-dei-beccaria.html
# Saved: page_59\glicine.html
# Saved: page_59\bottega-lucia.html
# Saved: page_59\villa-naj.html
# Saved: page_59\giannino-dal-1899.html
# Saved: page_59\acciuga.html
# Saved: page_59\concezione-restaurant.html
# Saved: page_59\locanda-perbellini-al-mare.html
# Saved: page_59\meraviglioso-osteria-moderna.html
# Saved: page_59\gennaro-amitrano-1190752.html
# Saved: page_59\alici.html
# Saved: page_59\matteo-grandi.html
# Saved: page_59\il-giardinetto.html
# Saved: page_59\rimulas.html
# Saved: page_59\la-caravella-dal-1959.html
# Saved: page_59\locale.html
# Saved: page_59\san-martino155366.html
# Saved: page_60\chiaroscuro.html
# Saved: page_60\asina-luna.html
# Saved: page_60\il-barolino.html
# Saved: page_60\ca-d-frara.html
# Saved: page_60\faula.html
# Saved: page_60\il-piastrino.html
# Saved: page_60\il-rivale-l-osteria-di-palazzo.html
# Saved: page_60\boccon-divino.html
# Saved: page_60\lillo-tatini.html
# Saved: page_60\guido.html
# Saved: page_60\giardino-da-felicin.html
# Saved: page_60\antica-locanda-dell-orco.html
# Saved: page_60\risorgimento.html
# Saved: page_60\le-vele.html
# Saved: page_60\giardinetto.html
# Saved: page_60\trattoria-di-campagna.html
# Saved: page_60\kro.html
# Saved: page_60\makore.html
# Saved: page_60\il-chiosco-di-bacco.html
# Saved: page_60\lo-stornello.html
# Saved: page_61\il-flauto-di-pan.htmlSaved: page_61\razzo.html
# Saved: page_61\massimo-camia.html
# Saved: page_61\almato.html
#
# Saved: page_61\antica-moka.html
# Saved: page_61\luisl-stube.html
# Saved: page_61\baracca-storica-hostaria.html
# Saved: page_61\3-0-ciro-cascella.html
# Saved: page_61\la-pergola69016.html
# Saved: page_61\nascostoposto.html
# Saved: page_61\mezzolitro-vini-e-cucina.html
# Saved: page_61\adelaide.html
# Saved: page_61\duanima.html
# Saved: page_61\da-sapi.html
# Saved: page_61\sanbrite.html
# Saved: page_61\al-persef.html
# Saved: page_61\paca.html
# Saved: page_61\livello-1.html
# Saved: page_61\cenere-museum-bistrot.html
# Saved: page_61\w-villadorata-country-restaurant.html
# Saved: page_62\bramea.html
# Saved: page_62\quintessenza-1195965.html
# Saved: page_62\la-favellina.html
# Saved: page_62\josto.html
# Saved: page_62\toe-drue.html
# Saved: page_62\dimora-ulmo.html
# Saved: page_62\fattoria-delle-torri.html
# Saved: page_62\locanda-delle-grazie.html
# Saved: page_62\il-25.html
# Saved: page_62\buca-di-bacco.html
# Saved: page_62\da-miky.html
# Saved: page_62\dani-maison.html
# Saved: page_62\la-pineta136054.html
# Saved: page_62\osteria-il-maialetto.html
# Saved: page_62\posillipo.html
# Saved: page_62\la-primula.html
# Saved: page_62\l-erba-del-re.html
# Saved: page_62\lorenzo.html
# Saved: page_62\stefano-paganini-alla-corte-degli-alfieri.html
# Saved: page_62\arnaldo-clinica-gastronomica.html
# Saved: page_63\porcino.htmlSaved: page_63\la-gallina.html
#
# Saved: page_63\l-essenza-bistrot.html
# Saved: page_63\vini-da-gigio.html
# Saved: page_63\vignamare.html
# Saved: page_63\retroscena.html
# Saved: page_63\acqua-562821.html
# Saved: page_63\l-ortone.html
# Saved: page_63\gagini-social-restaurant.html
# Saved: page_63\li-galli.html
# Saved: page_63\il-circolino.html
# Saved: page_63\menabo-vino-e-cucina.html
# Saved: page_63\osteria-della-trippa.html
# Saved: page_63\il-poggio.html
# Saved: page_63\terra151934.html
# Saved: page_63\tenne-1191201.html
# Saved: page_63\osteria-il-cappello.html
# Saved: page_63\lunasia500267.html
# Saved: page_63\signore-te-ne-ringrazi-1202527.html
# Saved: page_63\bentoteca.html
# Saved: page_64\burje-1968.html
# Saved: page_64\bino-ricchebuono.html
# Saved: page_64\incalmo.html
# Saved: page_64\la-ciambella.html
# Saved: page_64\cortile-pepe.html
# Saved: page_64\casu-osteria-contemporanea.html
# Saved: page_64\bianca-sul-lago.html
# Saved: page_64\mirabelle-1190136.html
# Saved: page_64\enoteca-la-torre.html
# Saved: page_64\il-portolano.html
# Saved: page_64\il-bikini.html
# Saved: page_64\vecchia-marina.htmlSaved: page_64\abraxas-osteria.html
#
# Saved: page_64\su-gologone.html
# Saved: page_64\henri-restaurant.html
# Saved: page_64\deste.html
# Saved: page_64\de-minimi.htmlSaved: page_64\il-rivale-in-citta.html
# Saved: page_64\kohaku-1206448.html
#
# Saved: page_64\de-gustibus.html
# Saved: page_65\locanda-gesu-vecchio.htmlSaved: page_65\salsedine367.html
#
# Saved: page_65\al-malo-cucina-e-miscelazione.html
# Saved: page_65\famiglia-rana.html
# Saved: page_65\flurin.html
# Saved: page_65\il-cavallo-scosso.html
# Saved: page_65\consorzio.html
# Saved: page_65\carpe-noctem-et-diem.html
# Saved: page_65\taverna-estia.html
# Saved: page_65\rossellinis.html
# Saved: page_65\terrazza-gallia.html
# Saved: page_65\nello.html
# Saved: page_65\locanda-san-martino.html
# Saved: page_65\teresita-by-giardino-di-mari.html
# Saved: page_65\marc-lanteri.html
# Saved: page_65\atto-di-vito-mollica.html
# Saved: page_65\andrea-larossa.html
# Saved: page_65\il-principe.html
# Saved: page_65\otto-geleng.html
# Saved: page_65\magazzino-52.html
# Saved: page_66\josef-stube.html
# Saved: page_66\cafe-cracco.html
# Saved: page_66\la-barca-147567.html
# Saved: page_66\luciano-cucina-italiana.html
# Saved: page_66\l-imbuto.html
# Saved: page_66\casa-leali.html
# Saved: page_66\aalto.html
# Saved: page_66\impronta.html
# Saved: page_66\oishi-teramo.html
# Saved: page_66\casa-perrotta-restaurant.html
# Saved: page_66\vite.html
# Saved: page_66\osteria-grande.html
# Saved: page_66\faletta-1881.html
# Saved: page_66\da-armando-al-pantheon.html
# Saved: page_66\quadri-bistrot.html
# Saved: page_66\trattoria-dall-antonia.html
# Saved: page_66\ling-s-ravioleria-migrante.html
# Saved: page_66\aldivino.html
# Saved: page_66\don-alfonso-1890-san-barbato.html
# Saved: page_66\selvatico.html
# Saved: page_67\la-posta161422.html
# Saved: page_67\materia-1203255.html
# Saved: page_67\prato-gaio.html
# Saved: page_67\il-marchese-osteria-mercato-liquori.html
# Saved: page_67\i-rodella.html
# Saved: page_67\osteria-1861.html
# Saved: page_67\stefenelli-desk.html
# Saved: page_67\l-arcade-1196110.html
# Saved: page_67\il-narciso.html
# Saved: page_67\vescovo-moro.html
# Saved: page_67\locanda-belvedere.html
# Saved: page_67\la-musa.html
# Saved: page_67\enoteca-di-buttrio.html
# Saved: page_67\santamonica.html
# Saved: page_67\antica-trattoria-al-gallo-1909.html
# Saved: page_67\voce-aimo-e-nadia.html
# Saved: page_67\osteria-il-granaio.html
# Saved: page_67\spoon.html
# Saved: page_67\sottovoce.html
# Saved: page_67\osteria-l-abbicci.html
# Saved: page_68\locanda-della-luna.html
# Saved: page_68\il-frantoio-453239.html
# Saved: page_68\felter-alle-rose.html
# Saved: page_68\hostaria-di-bricai.html
# Saved: page_68\osteria-dello-strecciolo.html
# Saved: page_68\indigeno.html
# Saved: page_68\riccio-restaurant.html
# Saved: page_68\il-grifone.html
# Saved: page_68\casa-sgarra.html
# Saved: page_68\mu-dimsum.html
# Saved: page_68\la-limonaia.html
# Saved: page_68\il-molo.html
# Saved: page_68\casa-federici.html
# Saved: page_68\kresios.html
# Saved: page_68\hosteria-del-platano.html
# Saved: page_68\cetaria.html
# Saved: page_68\locanda-martinelli.html
# Saved: page_68\nerina.html
# Saved: page_68\sensi536205.html
# Saved: page_68\chat-qui-rit.html
# Saved: page_69\borgia-milano.html
# Saved: page_69\el-brite-di-larieto.html
# Saved: page_69\osteria-del-viandante.html
# Saved: page_69\ostaria-tyrol.html
# Saved: page_69\bu-r.html
# Saved: page_69\la-rucola-2-0.html
# Saved: page_69\impronte.html
# Saved: page_69\la-cucina-de-mibabbo.html
# Saved: page_69\da-attilio.html
# Saved: page_69\al-baccanale.html
# Saved: page_69\da-luciano.html
# Saved: page_69\stefano-mocellin-al-padovanino.html
# Saved: page_69\estro.html
# Saved: page_69\il-frantoio-1090839.html
# Saved: page_69\palazzo-branciforte.html
# Saved: page_69\carter-oblio.html
# Saved: page_69\1908.html
# Saved: page_69\sostansa.html
# Saved: page_69\trattoria-da-lucio.html
# Saved: page_69\la-risacca-blu.html
# Saved: page_70\bis-osteria-italiana-contemporanea.html
# Saved: page_70\dallo-zio.html
# Saved: page_70\reale.html
# Saved: page_70\qafiz.html
# ...
# Saved: page_76\barbieri.html
# Saved: page_76\al-carroponte.html
# Saved: page_77\villa-tiboldi.html
# Saved: page_77\trattoria-la-colonna.html
# Saved: page_77\il-turacciolo.html
# Saved: page_77\matteo-caffe-e-cucina.html
# Saved: page_77\vecchio-ristoro.html
# Saved: page_77\lord-nelson.html
# Saved: page_77\da-felice.html
# Saved: page_77\la-parolina.html
# Saved: page_77\il-palagio.html
# Saved: page_77\storie-d-amore.html
# Saved: page_77\trattoria-da-probo.html
# Saved: page_77\macelleria-motta.html
# Saved: page_77\frosio.html
# Saved: page_77\commercio-e-mas-ci.html
# Saved: page_77\pantagruele.html
# Saved: page_77\locanda-gulfi.html
# Saved: page_77\antica-corona-reale.html
# Saved: page_77\la-madia175149.html
# Saved: page_77\carlo-magno.html
# Saved: page_77\cannavacciuolo-vineyard.html
# Saved: page_78\podere-belvedere-tuscany.html
# Saved: page_78\elementi.html
# Saved: page_78\equilibrio.html
# Saved: page_78\oblige.html
# Saved: page_78\pierre-trattoria-sartoriale.html
# Saved: page_78\locanda-san-michele.html
# Saved: page_78\antica-farmacia.html
# Saved: page_78\la-porta-antica.html
# Saved: page_78\abitat.html
# Saved: page_78\idylio-by-apreda.html
# Saved: page_78\osteria-del-mare-gia-il-votapentole.html
# Saved: page_78\parco-gambrinus.html
# Saved: page_78\taverna-da-ciacco.html
# Saved: page_78\ai-do-campanili.html
# Saved: page_78\osteria-dai-coghi.html
# Saved: page_78\locanda-dell-arcimboldo.html
# Saved: page_78\babette394187.html
# Saved: page_78\zur-kaiserkron.html
# Saved: page_78\agriturismo-il-cavallino.html
# Saved: page_78\lu-pisantinu.html
# Saved: page_79\la-kucina.html
# Saved: page_79\osteria-francescana.html
# Saved: page_79\aria-1197785.html
# Saved: page_79\feria.html
# Saved: page_79\gusto-by-sadler.html
# Saved: page_79\da-gorini.html
# Saved: page_79\coeur-de-bois.html
# Saved: page_79\apostelstube.html
# Saved: page_79\grual.html
# Saved: page_79\michelasso.html
# Saved: page_79\cappuccini-cucina-san-francesco.html
# Saved: page_79\la-zanzara.html
# Saved: page_79\locanda-di-nonna-ida.html
# Saved: page_79\oltre.html
# Saved: page_79\locanda-dei-cantu.html
# Saved: page_79\villa-pignano.html
# Saved: page_79\locanda-stella-d-oro.html
# Saved: page_79\alla-pasina.html
# Saved: page_79\cucina-eat.html
# Saved: page_79\mater-bistrot.html
# Saved: page_80\local.html
# Saved: page_80\caracol.html
# Saved: page_80\osteria-dell-arco.html
# Saved: page_80\andree.html
# Saved: page_80\octavin.html
# Saved: page_80\tre-scalini.html
# Saved: page_80\l-acquario.html
# Saved: page_80\le-nove-scodelle.html
# Saved: page_80\contrada-bricconi.html
# Saved: page_80\san-giorgio1077324.html
# Saved: page_80\la-locanda-di-fabio-e-vale.html
# Saved: page_80\ad-astra.html
# Saved: page_80\casa-coloni.html
# Saved: page_80\leon-d-oro146788.html
# Saved: page_80\zest-1212030.html
# Saved: page_80\azotea.html
# Saved: page_80\al-gatto-verde.html
# Saved: page_80\terrazza-tiberio.html
# Saved: page_80\nole.html
# Saved: page_80\terramira.html
# Saved: page_81\l-ostreria-fratelli-pavesi.html
# Saved: page_81\osmosi.html
# Saved: page_81\cracco-portofino.html
# Saved: page_81\chalet-gerard.html
# Saved: page_81\kelina-fine-dine.html
# Saved: page_81\casa-della-rocca.html
# Saved: page_81\paolo-griffa-al-caffe-nazionale.html
# Saved: page_81\pellico-3.html
# Saved: page_81\masseria-moroseta.html
# Saved: page_81\fradis-minoris.html
# Saved: page_81\trattoria-margherita.html
# Saved: page_81\olmo.html
# Saved: page_81\millo-ristorante.html
# Saved: page_81\amano-1211513.html
# Saved: page_81\belvedere-1203863.html
# Saved: page_81\osteria-dei-maltagliati.html
# Saved: page_81\cocun-cellar-restaurant.html
# Saved: page_81\le-bistrot-321392.html
# Saved: page_81\stilla.html
# Saved: page_81\ai-porteghi-bistrot.html
# Saved: page_82\oltremare.html
# Saved: page_82\osteria-ophis.html
# Saved: page_82\sintesi.html
# Saved: page_82\aminta-resort.html
# Saved: page_82\glam-enrico-bartolini.html
# Saved: page_82\remulass.html
# Saved: page_82\andrea-aprea.html
# Saved: page_82\pentole-e-provette.html
# Saved: page_82\locanda-dei-banchieri.html
# Saved: page_82\urubamba-1199094.html
# Saved: page_82\l-agave.html
# Saved: page_82\il-tempo-nuovo.html
# Saved: page_82\san-tommaso-10.html
# Saved: page_82\principe-di-belludia.html
# Saved: page_82\zanze-xvi.html
# Saved: page_82\cut-ristorante.html
# Saved: page_82\soms.html
# Saved: page_82\dattilo.html
# Saved: page_82\maragoncello.html
# Saved: page_82\hyle.html
# Saved: page_83\al-moro.html
# Saved: page_83\li-somari.html
# Saved: page_83\anastasia-1199091.html
# Saved: page_83\une.html
# Saved: page_83\qualia.html
# Saved: page_83\cala-luna.html
# Saved: page_83\antiche-carampane.html
# Saved: page_83\phi-restaurant-giancarlo-morelli.html
# Saved: page_83\wisteria.html
# Saved: page_83\coria.html
# Saved: page_83\lanzani-bottega-bistrot.html
# Saved: page_83\colline-ciociare.html
# Saved: page_83\clandestino-susci-bar.html
# Saved: page_83\al-borgo126456.html
# Saved: page_83\la-conchiglia.html
# Saved: page_83\le-petit-restaurant.html
# Saved: page_83\gassenwirt.html
# Saved: page_83\wood460913.html
# Saved: page_83\miramonti-l-altro.html
# Saved: page_83\l-argaj.html
# Saved: page_84\la-gioconda.html
# Saved: page_84\gardenia.html
# Saved: page_84\ll-portico.html
# Saved: page_84\85-bistrot.html
# Saved: page_84\oste-scuro-finsterwirt.html
# Saved: page_84\strattoria.html
# Saved: page_84\osteria-la-torre.html
# Saved: page_84\acquolina.html
# Saved: page_84\pietramare-natural-food.html
# Saved: page_84\bele.html
# Saved: page_84\dal-dosso-salamensa.html
# Saved: page_84\cafe-quinson.html
# Saved: page_84\essentia.html
# Saved: page_84\la-botte-1198676.html
# Saved: page_84\gennaro-di-pace.html
# Saved: page_84\trattoria-da-amerigo.html
# Saved: page_84\san-martino-26.html
# Saved: page_84\trippini.html
# Saved: page_84\da-cecco.html
# Saved: page_84\osteria-taviani.html
# Saved: page_85\daniela.html
# Saved: page_85\il-labirinto.html
# Saved: page_85\trattoria-porteri.html
# Saved: page_85\lou-ressignon.html
# Saved: page_85\perbacco-vini-e-cucina.html
# Saved: page_85\l-osteria-del-castellazzo.html
# Saved: page_85\al-becco-della-civetta.html
# Saved: page_85\pescarino-sapori-di-terra-e-di-mare.html
# Saved: page_85\da-fausto.html
# Saved: page_85\el-molin.html
# Saved: page_85\badessa.html
# Saved: page_85\borgo-poscolle.html
# Saved: page_85\dal-pescatore.html
# Saved: page_85\la-veranda160871.html
# Saved: page_85\la-porta-restaurant.html
# Saved: page_85\loewengrube.html
# Saved: page_85\retrobottega.html
# Saved: page_85\gia-sotto-l-arco.html
# Saved: page_85\saffron252973.html
# Saved: page_85\la-terrazza160806.html
# Saved: page_86\castagneto.html
# Saved: page_86\il-focarile.html
# Saved: page_86\osteria-san-giulio.html
# Saved: page_86\la-locanda-del-cardinale.html
# Saved: page_86\la-fermata.html
# Saved: page_86\john-restaurant-casamadre.html
# Saved: page_86\kanton-restaurant.html
# Saved: page_86\cascina-lautier.html
# Saved: page_86\taverna-del-castello.html
# Saved: page_86\januarius.html
# Saved: page_86\antica-osteria-da-penacio.html
# Saved: page_86\marina-grande.html
# Saved: page_86\sot-ajarchi.html
# Saved: page_86\piano-35.html
# Saved: page_86\trattoria-al-cacciatore-della-subida.html
# Saved: page_86\antine.html
# Saved: page_86\il-carpaccio.html
# Saved: page_86\feel.html
# Saved: page_86\aqua-crua.html
# Saved: page_86\walter-redaelli.html
# Saved: page_87\d-o.html
# Saved: page_87\osteria-del-gran-fritto334900.html
# Saved: page_87\il-moro.html
# Saved: page_87\il-pavone.html
# Saved: page_87\osteria-le-logge.html
# Saved: page_87\damini-macelleria-affini.html
# Saved: page_87\ristofante.html
# Saved: page_87\stube-ladina.html
# Saved: page_87\sarti-del-gusto.html
# Saved: page_87\all-enoteca.html
# Saved: page_87\osteria-de-l-umbreleer.html
# Saved: page_87\da-peppe.html
# Saved: page_87\ventuno-1.html
# Saved: page_87\osteria-ardenga.html
# Saved: page_87\accademia-ristorante.html
# Saved: page_87\roof-garden.html
# Saved: page_87\villa-baroni.html
# Saved: page_87\il-giardino-delle-esperidi.html
# Saved: page_87\casa-vissani.html
# Saved: page_87\molteni.html
# Saved: page_88\osteria-dell-oca-bianca.html
# Saved: page_88\doc.html
# Saved: page_88\trattoria-pennestri.html
# Saved: page_88\essencia-restaurant.html
# Saved: page_88\sapio.html
# Saved: page_88\locanda-del-molino.html
# Saved: page_88\indinio.html
# Saved: page_88\casa-mazzucchelli.html
# Saved: page_88\mare.html
# Saved: page_88\il-sereno-al-lago.html
# Saved: page_88\del-lago.html
# Saved: page_88\l-olivo.html
# Saved: page_88\caffe-la-crepa.html
# Saved: page_88\quattro-sensi.html
# Saved: page_88\la-canonica-1186584.html
# Saved: page_88\calvi-ristorante.html
# Saved: page_88\opificio.html
# Saved: page_88\osteria-del-posto.html
# Saved: page_88\principe-cerami.html
# Saved: page_88\hostaria-dai-musi.html
# Saved: page_89\trattoria-del-bivio.html
# Saved: page_89\locanda-del-marinaio.html
# Saved: page_89\la-casa-degli-spiriti.html
# Saved: page_89\la-veranda161442.html
# Saved: page_89\enoclub.html
# Saved: page_89\nove.html
# Saved: page_89\i-salotti.html
# Saved: page_89\kurbishof.html
# Saved: page_89\osteria-del-gran-fritto.html
# Saved: page_89\il-doretto.html
# Saved: page_89\dentella.html
# Saved: page_89\faraglioni-restaurant.html
# Saved: page_89\trattoria-contemporanea.html
# Saved: page_89\all-osteria-bottega.html
# Saved: page_89\il-gabbiano.html
# Saved: page_89\tano-passami-l-olio-1184698.html
# Saved: page_89\sui-generis.html
# Saved: page_89\il-fuoco-sacro.html
# Saved: page_89\ensama-pesce.html
# Saved: page_89\futura-osteria.html
# Saved: page_90\700.html
# Saved: page_90\uovodiseppia-milano.html
# Saved: page_90\forma-contemporary-restaurant.html
# Saved: page_90\osteria-alla-chiesa.html
# Saved: page_90\campo-cedro.html
# Saved: page_90\enoteca-meucci.html
# Saved: page_90\contrada.html
# Saved: page_90\granoturco-bistrot.html
# Saved: page_90\anto-e-robi.html
# Saved: page_90\casa-rapisarda.html
# Saved: page_90\radimare.html
# Saved: page_90\la-palta.html
# Saved: page_90\la-loggia-bistro.html
# Saved: page_90\il-cantuccio.html
# Saved: page_90\sucar-brusc.html
# Saved: page_90\i-5-sensi.html
# Saved: page_90\il-falconiere.html
# Saved: page_90\ahime.html
# Saved: page_90\repubblica-di-perno.html
# Saved: page_90\da-marino-al-st-remy.html
# Saved: page_91\lofficina.html
# Saved: page_91\villa-lattanzi.html
# Saved: page_91\la-rima.html
# Saved: page_91\pescheria.html
# Saved: page_91\frades-la-terrazza.html
# Saved: page_91\riva-1211834.html
# Saved: page_91\vascello-d-oro.html
# Saved: page_91\dogma.html
# Saved: page_91\romane.html
# Saved: page_91\il-desco.html
# Saved: page_91\osteria-il-moro.html
# Saved: page_91\la-casina.html
# Saved: page_91\inalto-alfio-ghezzi-dolomites.html
# Saved: page_91\locanda-solagna.html
# Saved: page_91\hostaria-da-franz.html
# Saved: page_91\osteria-del-miglio-2-10.html
# Saved: page_91\locanda-altobelli.html
# Saved: page_91\savo.html
# Saved: page_91\il-bavaglino-1206991.html
# Saved: page_91\il-grottino-1204740.html
# Saved: page_92\cravero.html
# Saved: page_92\osteria-da-fiore.html
# Saved: page_92\castel-toblino.html
# Saved: page_92\u-vulesce.html
# Saved: page_92\miseria-e-nobilta.html
# Saved: page_92\ginevra.html
# Saved: page_92\san-quintino-resort.html
# Saved: page_92\antichi-sapori.html
# Saved: page_92\osteria-bartolini.html
# Saved: page_92\al-camin.html
# Saved: page_92\evan-s.html
# Saved: page_92\caffe-meletti.html
# Saved: page_92\i-pupi.html
# Saved: page_92\luigi-pomata.html
# Saved: page_92\malenco.html
# Saved: page_92\da-alighiero.html
# Saved: page_92\namo-ristobottega.html
# Saved: page_92\io-luigi-taglienti.html
# Saved: page_92\claudio-ristorante.html
# Saved: page_92\al-gambero.html
# Saved: page_93\terrazza-bartolini.html
# Saved: page_93\la-cerreta-osteria.html
# Saved: page_93\mater.html
# Saved: page_93\le-vie-del-borgo.html
# Saved: page_93\l-atelier-26.html
# Saved: page_93\tenuta-casa-virginia.html
# Saved: page_93\osteria-da-cippi.html
# Saved: page_93\il-riccio.html
# Saved: page_93\rosso-di-sera.html
# Saved: page_93\dissapore-di-andrea-catalano.html
# Saved: page_93\osteria-del-tempo-perso.html
# Saved: page_93\posta.html
# Saved: page_93\laurin.html
# Saved: page_93\regallo.html
# Saved: page_93\lio-pellegrini.html
# Saved: page_93\locanda-del-pilone.html
# Saved: page_93\ca-7.html
# Saved: page_93\rifugio-col-alt.html
# Saved: page_93\laghetto.html
# Saved: page_93\zafferano-161583.html
# Saved: page_94\particolare-di-siena.html
# Saved: page_94\baita-fraina.html
# Saved: page_94\magnagallo.html
# Saved: page_94\i-5-campanili.html
# Saved: page_94\castello-malvezzi.html
# Saved: page_94\vitis.html
# Saved: page_94\osteria-da-nando.html
# Saved: page_94\elefante.html
# Saved: page_94\a-paranza.html
# Saved: page_94\aciniello.html
# Saved: page_94\baretto-di-san-vigilio.html
# Saved: page_94\l-acciuga.html
# Saved: page_94\pasha.html
# Saved: page_94\osteria-expanificio.html
# Saved: page_94\osteria-magona.html
# Saved: page_94\agora.html
# Saved: page_94\magnolia.html
# Saved: page_94\le-chiavi-d-oro.html
# Saved: page_94\locanda-del-barone.html
# Saved: page_94\dispensa-pani-e-vini-franciacorta.html
# Saved: page_95\fiamma-cremisi.html
# Saved: page_95\ladinia.html
# Saved: page_95\la-locanda-di-pietracupa.html
# Saved: page_95\ai-burattini.html
# Saved: page_95\marsupino.html
# Saved: page_95\saporium.html
# Saved: page_95\locanda-alpina.html
# Saved: page_95\piazza-duomo.html
# Saved: page_95\locanda-mariella.html
# Saved: page_95\piazzetta-milu.html
# Saved: page_95\feva.html
# Saved: page_95\la-stua-de-michil.html
# Saved: page_95\da-pode.html
# Saved: page_95\trattoria-rigoletto.html
# Saved: page_95\antico-ristorante-pagnanelli.html
# Saved: page_95\la-sosta.html
# Saved: page_95\residenza-del-lago.html
# Saved: page_95\enoteca-di-canelli.html
# Saved: page_95\molin-vecio.html
# Saved: page_95\battaglino.html
# Saved: page_96\palazzaccio.html
# Saved: page_96\el-gato.html
# Saved: page_96\romolo-mare.html
# Saved: page_96\dolia-gaeta.html
# Saved: page_96\da-miro-alla-lanterna.html
# Saved: page_96\lamberti.html
# Saved: page_96\boccondivino.html
# Saved: page_96\le-cicale.html
# Saved: page_96\pernambucco.html
# Saved: page_96\collina.html
# Saved: page_96\mistral126374.html
# Saved: page_96\i-pifferi.html
# Saved: page_96\magiarge-osteria-contemporanea.html
# Saved: page_96\stube-gourmet.html
# Saved: page_96\alla-fassa.html
# Saved: page_96\due-colombe.html
# Saved: page_96\nido-del-picchio.html
# Saved: page_96\il-tino.html
# Saved: page_96\pinocchio.html
# Saved: page_96\il-fiorile.html
# Saved: page_97\miil.html
# Saved: page_97\ortica.html
# Saved: page_97\nin.html
# Saved: page_97\antica-locanda.html
# Saved: page_97\blum-1208129.html
# Saved: page_97\poli-alla-stazione.html
# Saved: page_97\scola.html
# Saved: page_97\osteria-la-pimpinella.html
# Saved: page_97\villa-salina.html
# Saved: page_97\frades-porto-cervo.html
# Saved: page_97\antica-cucina-1983.html
# Saved: page_97\baita-pie-tofana.html
# Saved: page_97\mingone.html
# Saved: page_97\12-ristorante.html
# Saved: page_97\villa-elena.html
# Saved: page_97\duomo.html
# Saved: page_97\kuppelrain.html
# Saved: page_97\da-tonino.html
# Saved: page_97\locanda-baggio.html
# Saved: page_97\violetta.html
# Saved: page_98\villa-pizzini.html
# Saved: page_98\osteria-casale-ferrovia.html
# Saved: page_98\moi-omakase.html
# Saved: page_98\george-restaurant.html
# Saved: page_98\mima.html
# Saved: page_98\il-cedro.html
# Saved: page_98\al-baliaggio.html
# Saved: page_98\materia.html
# Saved: page_98\l-asinello.html
# Saved: page_98\un-piano-nel-cielo.html
# Saved: page_98\mood-osteria.html
# Saved: page_98\acqua-1201998.html
# Saved: page_98\53-untitled.html
# Saved: page_98\i-tenerumi.html
# Saved: page_98\essenza1157118.html
# Saved: page_98\suscettibile.html
# Saved: page_98\gnocchetto.html
# Saved: page_98\capogiro.html
# Saved: page_98\la-piemontese.htmlSaved: page_98\meta-ristorante.html
#
# Saved: page_99\sotto-l-arco.html
# Saved: page_99\iris-ristorante.html
# Saved: page_99\orma-roma.html
# Saved: page_99\hebbo-wine-deli.html
# Saved: page_99\shiroya.html
# Saved: page_99\sa-cardiga-e-su-schironi.html
# Saved: page_99\erbaluigia.html
# Saved: page_99\nazionale.html
# Saved: page_99\locanda-53-supper-club.html
# Saved: page_99\osteria-europa.html
# Saved: page_99\borgo-sant-anna.html
# Saved: page_99\zia.html
# Saved: page_99\eggentaler.html
# Saved: page_99\crub.html
# Saved: page_99\peperosa.html
# Saved: page_99\gu-sta-re-oltrecucina.html
# Saved: page_99\rendener-alpine-food.html
# Saved: page_99\de-len.html
# Saved: page_99\umami-1211596.html
# Saved: page_99\visione-restaurant-and-living.html
# Saved: page_100\acerorosso.html
# Saved: page_100\cafe-les-paillotes.html

# %% [markdown]
# ## Parsing

# %% [markdown]
# We parse HTML files for Michelin restaurants to extract key information (e.g., name, address, cuisine, facilities), and save each restaurant's data as an individual .tsv file.

# %%
from bs4 import BeautifulSoup
import os
import csv

def parse_restaurant_html(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        soup = BeautifulSoup(file, "html.parser")

    # Initialize dictionary with default empty strings
    data = {
        "restaurantName": '',
        "address": '',
        "city": '',
        "postalCode": '',
        "country": "Italy",
        "priceRange": '',
        "cuisineType": '',
        "description": '',
        "facilitiesServices": '',
        "creditCards": '',
        "phoneNumber": '',
        "website": ''
    }

    # Extract restaurant name
    name_tag = soup.find("h1", class_="data-sheet__title")
    if name_tag:
        data["restaurantName"] = name_tag.get_text(strip=True)

    # Extract address information
    address_tag = soup.find_all("div", class_="data-sheet__block--text")
    if address_tag:
        full_address = address_tag[0].get_text(strip=True)
        address_parts = full_address.split(', ')
        if len(address_parts) >= 3:
            data["country"] = address_parts[-1]
            data["postalCode"] = address_parts[-2]
            data["city"] = address_parts[-3]
            data["address"] = ', '.join(address_parts[:-3])
        elif len(address_parts) == 2:
            data["address"], data["city"] = address_parts
        else:
            data["address"] = full_address

    # Extract price range and cuisine type
    if len(address_tag) > 1:
        full_price_type = address_tag[1].get_text(strip=True)
        price_type_list = full_price_type.split()
        if price_type_list:
            data["priceRange"] = price_type_list[0]
            data["cuisineType"] = ' '.join(price_type_list[2:])

    # Extract description
    description_tag = soup.find("div", class_="data-sheet__description")
    if description_tag:
        data["description"] = description_tag.get_text(strip=True)

    # Extract facilities and services
    facilities_section = soup.find('div', class_="restaurant-details__services")
    if facilities_section:
        services = [li.get_text(strip=True) for li in facilities_section.find_all('li')]
        data["facilitiesServices"] = ', '.join(services)

    # Extract accepted credit cards
    credit_card_tags = soup.find_all("div", class_="restaurant-details__services--info")
    creditCards = []
    for tag in credit_card_tags:
        for img in tag.find_all("img"):
            if 'data-src' in img.attrs:
                credit_card_name = os.path.basename(img['data-src']).split('-')[0]
                creditCards.append(credit_card_name.title())
    data["creditCards"] = ', '.join(creditCards) if creditCards else ''

    # Extract phone number
    phone_tag = soup.find("div", class_="collapse__block-item")
    if phone_tag:
        data["phoneNumber"] = phone_tag.get_text(strip=True)

    # Extract restaurant website
    div_web = soup.find('div', class_='collapse__block-item link-item')
    if div_web:
        web_tag = div_web.find('a', class_='link js-dtm-link')
        if web_tag and web_tag.get('href'):
            data["website"] = web_tag.get('href')

    # Save to .tsv file
    output_file = file_path.replace(".html", ".tsv")
    with open(output_file, mode='w', encoding='utf-8') as file:
        keys = list(data.keys())
        dict_writer = csv.DictWriter(file, fieldnames=keys, delimiter='\t')
        dict_writer.writeheader()
        dict_writer.writerow(data)

    return data

# %% [markdown]
# Now, we process each restaurant's HTML file to extract data using concurrent threads, making the data collection process more efficient. Once all files are processed, we gather the generated .tsv files from each folder, read them into individual DataFrames, and then concatenate them into a single, unified DataFrame. Finally, we save this combined dataset to a single .tsv file, which consolidates all restaurant information for easy analysis and access.

# %%
import os
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# Base directory containing the HTML files
base_directory = r"C:\Users\Utente\OneDrive - uniroma1.it\Esami\ADM\Homework 3"


# Define the function to process each HTML file
def process_restaurant_file(file_info):
    filename, folder_path = file_info
    file_path = os.path.join(folder_path, filename)
    restaurant_data = parse_restaurant_html(file_path)
    return restaurant_data

# Collect all files to process
files_to_process = []
for folder in os.listdir(base_directory):
    folder_path = os.path.join(base_directory, folder)
    if os.path.isdir(folder_path):
        for filename in os.listdir(folder_path):
            if filename.endswith(".html"):
                files_to_process.append((filename, folder_path))

# Set up concurrent processing
with ThreadPoolExecutor() as executor:
    # Schedule each file to be processed concurrently
    futures = {executor.submit(process_restaurant_file, file_info): file_info for file_info in files_to_process}

# Combine all created .tsv files into a single DataFrame

# List to collect each DataFrame
all_data = []

# Iterate over each folder in the base directory
for folder in os.listdir(base_directory):
    folder_path = os.path.join(base_directory, folder)
    if os.path.isdir(folder_path):
        # Iterate over each .tsv file in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith(".tsv"):
                file_path = os.path.join(folder_path, filename)
                # Read each .tsv file and append to the list
                df = pd.read_csv(file_path, sep='\t',dtype={'postalCode': str}, keep_default_na=False)
                all_data.append(df)

# Concatenate all individual DataFrames into one combined DataFrame
data = pd.concat(all_data, ignore_index=True)

# %% [markdown]
# We notice that there are some missing values regarding the restaurants' websites, credit cards accepted and available services. We decide to *fill* these missing elements with an empty string.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   restaurantName      1982 non-null   object
#  1   address             1982 non-null   object
#  2   city                1982 non-null   object
#  3   postalCode          1982 non-null   object
#  4   country             1982 non-null   object
#  5   priceRange          1982 non-null   object
#  6   cuisineType         1982 non-null   object
#  7   description         1982 non-null   object
#  8   facilitiesServices  1982 non-null   object
#  9   creditCards         1982 non-null   object
#  10  phoneNumber         1982 non-null   object
#  11  website             1982 non-null   object
# dtypes: object(12)
# memory usage: 185.9+ KB

# %% [markdown]
# We check that now no missing values are present.

# %%
# Count the number of missing values in each column
missing_values = data.isnull().sum()
missing_values
# Out:
# restaurantName        0
# address               0
# city                  0
# postalCode            0
# country               0
# priceRange            0
# cuisineType           0
# description           0
# facilitiesServices    0
# creditCards           0
# phoneNumber           0
# website               0
# dtype: int64

# %% [markdown]
# Then, we save in a tsv file the dataset just created.

# %%
# Export data to a tsv file
output_file = "michelin_restaurants_data.tsv"
data.to_csv(output_file, sep='\t', index=False)

# %%
import pandas as pd
# export data to xlsx
data.to_excel("all_restaurants_data.xlsx", index=False)

# %% [markdown]
# # Search Engines

# %% [markdown]
# ## Conjunctive Search Engine
#
# + A conjunctive search engine retrieves documents that contain all specified search terms, meaning it only returns results where every query term appears.

# %% [markdown]
# First of all, we define a new column containing the text that will be compared to the user query. We define it as the union of restaurant type of cuisine and its description. This approach ensures that both cuisine and descriptive details are considered in matches, increasing the chances of accurate results. We then convert all text in the restaurant descriptions to lowercase to ensure that our search engine is case-insensitive. In other words, by standardizing the text format, we eliminate any discrepancies caused by different letter cases, allowing users to find relevant results regardless of capitalization. This step enhances the accuracy and usability of the search engine by treating terms like "Cuisine" and "cuisine" as identical.

# %%
# join the cuisine type and the description of the restaurant
data = pd.read_csv("michelin_restaurants_data.tsv", sep='\t', dtype={'postalCode': str})
data['text_to_compare'] = data['cuisineType'] + ' ' + data['description']
data['text_to_compare'].str.lower()
# Out:
# 0       farm to table, modern cuisine situated in the ...
# 1       campanian, seafood in a beautiful stone-vaulte...
# 2       piedmontese, contemporary this attractive rest...
# 3       modern cuisine, creative before it became famo...
# 4       seafood working in partnership with the nearby...
#                               ...
# 1977    japanese, asian one of the most popular restau...
# 1978    italian, creative villa aretusi is a pleasant ...
# 1979    modern cuisine a young chef with experience in...
# 1980    contemporary, piedmontese at this restaurant, ...
# 1981    innovative a young chef of undoubted talent is...
# Name: text_to_compare, Length: 1982, dtype: object

# %% [markdown]
# In this cell, we import essential libraries for text processing, including the Natural Language Toolkit (NLTK) to support our search engine’s linguistic capabilities. We download key resources like stopwords, tokenizers, and WordNet, which will help us standardize and clean the text by removing irrelevant words and lemmatizing terms to their base forms. Additionally, we include modules for handling regular expressions and JSON data, ensuring that our search engine can efficiently parse, process, and organize restaurant information.

# %%
data['postalCode']
all([len(data['postalCode'][j]) == 5 for j in range(len(data['postalCode']))])
# Out:
# True

# %%
# Imports for Search Engine

import nltk  # Natural Language Toolkit for text processing

# Download necessary NLTK resources
nltk.download('stopwords')       # Stopwords list to filter out common words (e.g., "the", "is")
nltk.download('punkt')           # Punkt tokenizer for sentence splitting and word tokenization
nltk.download('wordnet')         # WordNet lexical database for lemmatization

# Importing specific modules for text processing
import re                         # Regular expressions for text pattern matching
from nltk.corpus import stopwords # Stopwords list for filtering out common, irrelevant words
from nltk.stem import WordNetLemmatizer # WordNet-based lemmatizer for reducing words to base form
from nltk.tokenize import word_tokenize # Word tokenizer to split text into individual words
import json                       # JSON module for handling JSON data structures
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utente\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utente\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Utente\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Here, we define a function to preprocess text by cleaning, tokenizing, and normalizing it for our search engine. First, we convert text to lowercase, remove non-alphanumeric characters, and split it into individual words. We then remove stopwords and apply lemmatization to reduce each word to its base form, ensuring that our search engine captures the essential meaning of each term while discarding irrelevant details.

# %%
def preprocess_text(text):
    text = text.lower()  # Convert text to lowercase
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Remove non-alphanumeric characters
    token = word_tokenize(text)  # Tokenize the text into words
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    token = [word for word in token if word not in stop_words]  # Keep only words not in stopwords
    
    # Choose between stemming or lemmatization for standardization
    # We can uncomment the following lines to use stemming:
    # stemmer = nltk.PorterStemmer()
    # token = [stemmer.stem(word) for word in token]  # Apply stemming to each word (choose based on preference)
    
    # Apply lemmatization to each word
    lemmatizer = WordNetLemmatizer()
    token = [lemmatizer.lemmatize(word) for word in token]
    
    return token

# %% [markdown]
# Now, we build a vocabulary and an inverted index to efficiently manage and search terms across restaurant descriptions. First, we assign a unique term ID to each word encountered, storing it in the vocabulary, and then we map each term ID to the document IDs where the term appears, creating the inverted index. Finally, we save the vocabulary as a CSV file and the inverted index as a JSON file, providing a structured and searchable representation of the text data for our search engine.

# %%
def create_vocabulary_and_inverted_index(descriptions):
    vocabulary = {}         # Dictionary to store unique words with their term IDs
    inverted_index = {}      # Dictionary to store the inverted index
    term_id = 0

    # Loop through each description, assigning a unique doc_id to each
    for doc_id, text in enumerate(descriptions):
        tokens = preprocess_text(text)  # Preprocess and tokenize the text

        for token in tokens:
            # If the word is not in the vocabulary, add it with a new term_id
            if token not in vocabulary:
                vocabulary[token] = term_id
                term_id += 1

            # Get the term_id of the word
            tid = vocabulary[token]

            # Add doc_id to the inverted index for this term_id
            if tid not in inverted_index:
                inverted_index[tid] = []
            if doc_id not in inverted_index[tid]:
                inverted_index[tid].append(doc_id)

    # Save the vocabulary to a CSV file
    with open('vocabulary.csv', 'w') as vocab_file:
        for word, tid in vocabulary.items():
            vocab_file.write(f"{word},{tid}\n")

    # Save the inverted index to a JSON file
    with open('inverted_index.json', 'w') as index_file:
        json.dump(inverted_index, index_file)

    return vocabulary, inverted_index

# %% [markdown]
# We implement a function to handle conjunctive queries, allowing us to search for restaurants that contain all specified terms in their descriptions. We process the query by mapping each search term to its unique term ID, then use the inverted index to retrieve only the documents (restaurants) containing all query terms. This approach ensures that our search engine provides precise results by returning only the restaurant data that fully matches the user’s search criteria.

# %%
def conjunctive_query(query, vocabulary, inverted_index, restaurant_data):
    # Preprocess the query text and convert it to term IDs using the vocabulary
    query_tokens = preprocess_text(query)
    query_term_ids = [vocabulary.get(token) for token in query_tokens if token in vocabulary]

    # If no terms from the query are found in the vocabulary, return an empty result
    if not query_term_ids:
        return []

    # Find documents containing all term IDs from the query
    doc_lists = [set(inverted_index[tid]) for tid in query_term_ids if tid in inverted_index]

    # Intersect document lists to get documents that contain all query terms
    if doc_lists:
        matching_docs = set.intersection(*doc_lists)
    else:
        matching_docs = set()

    # Return the corresponding restaurant data for matching documents
    results_df = restaurant_data[restaurant_data.index.isin(matching_docs)]

    # Return just the key information (restaurant name, address, description and website)
    return results_df[['restaurantName', 'address', 'description', 'website']]

# %% [markdown]
# We now test our search engine by running a sample query for "modern seasonal cuisine" to see if it accurately returns matching restaurants. We generate the vocabulary and inverted index from our dataset and use them to process the query, displaying the names and descriptions of any restaurants that meet the criteria. Finally, we summarize the results by indicating the total number of matches, which helps verify the effectiveness of our search engine in retrieving relevant data.

# %%
# Define the query to test the search engine
query = 'modern roman cuisine'

# Build the vocabulary and inverted index from the descriptions
vocabulary, inverted_index = create_vocabulary_and_inverted_index(data['text_to_compare'])

# Run the conjunctive query
results = conjunctive_query(query, vocabulary, inverted_index, data)

# Display the results
print(f"Results for the query '{query}':")
results
# Out:
# Results for the query 'modern roman cuisine':
#                 restaurantName                 address  \
# 198          Scrigno del Duomo         piazza Duomo 29
# 480               Ponte Pietra     via Ponte Pietra 34
# 568                    Gellius        calle Pretoria 6
# 828                       Gina   via Croce di Città 25
# 1694  La Locanda del Cardinale  piazza del Vescovado 8
#
#                                             description  \
# 198   This restaurant boasts a stunning setting that...
# 480   An old building next to the Roman bridge Ponte...
# 568   Gellius boasts a unique and atmospheric settin...
# 828   In the old town, a simple and informal locatio...
# 1694  A medieval house with stone arches, built over...
#
#                                      website
# 198         https://www.scrignodelduomo.com/
# 480        https://ristorantepontepietra.com
# 568        https://www.ristorantegellius.it/
# 828         http://www.ginacasaconcucina.com
# 1694  https://www.lalocandadelcardinale.com/

# %% [markdown]
# ## Ranked Search Engine
# The engine evaluates the importance of each term in each document (restaurant information) using TF-IDF (Term Frequency - Inverse Document Frequency). TF measures how often a term appears in a document, while IDF reduces the weights (the importance) of terms that are present in many documents, prioritizing unique and informative terms.

# %% [markdown]
# In this cell, we calculate the Term Frequency-Inverse Document Frequency (TF-IDF) for each word across all restaurant descriptions to measure the relevance of each term within each document. First, we compute Term Frequency (TF) and Document Frequency (DF) for each term, then use these values to calculate TF-IDF scores, which help identify the most significant words in each description. Finally, we create an inverted index with TF-IDF weights, enabling efficient retrieval of relevant documents based on keyword importance in our search engine.

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import math

def calculate_tf_idf(data, vocabulary):
    N = len(data)  # Total number of documents
    tf = defaultdict(lambda: defaultdict(int))  # Term Frequency (TF) for each document and term
    df = defaultdict(int)  # Document Frequency (DF) for each term
    tf_idf = defaultdict(lambda: defaultdict(float))  # TF-IDF scores for each document and term

    # Calculate TF and DF
    for doc_id, description in enumerate(data['text_to_compare']):
        tokens = preprocess_text(description)
        token_counts = defaultdict(int)
        
        for token in tokens:
            if token in vocabulary:
                token_id = vocabulary[token]
                token_counts[token_id] += 1
                tf[doc_id][token_id] = token_counts[token_id]

        # Increment DF for each unique token in the document
        for token_id in set(token_counts.keys()):
            df[token_id] += 1
    
    # Calculate TF-IDF
    for doc_id in tf.keys():
        for token_id, count in tf[doc_id].items():
            term_frequency = count
            epsilon = 1e-10  # Small constant to avoid division by zero
            inverse_document_frequency = math.log(N / (df[token_id] + epsilon))
            tf_idf[doc_id][token_id] = term_frequency * inverse_document_frequency

    # Normalize each document's TF-IDF vector and create an inverted index with normalized TF-IDF weights
    inverted_index = defaultdict(list)
    for doc_id, token_weights in tf_idf.items():
        doc_vector_norm = math.sqrt(sum(weight ** 2 for weight in token_weights.values()))
        for token_id, weight in token_weights.items():
            normalized_weight = weight / (doc_vector_norm + epsilon)  # Normalize each term's weight
            inverted_index[token_id].append((doc_id, normalized_weight))

    return inverted_index

# %% [markdown]
# Here, we implement a ranked search function that allows us to retrieve the top results based on similarity to a user query. We calculate TF-IDF scores for the query terms, then compute cosine similarity scores between the query and each document to rank the results. By selecting the highest-ranking matches, we ensure that our search engine returns the most relevant restaurant descriptions for each query.

# %%
def ranked_query(query, vocabulary, inverted_index, data, top_k=5):
    # Preprocess the query and convert terms to their IDs using the vocabulary
    query_tokens = preprocess_text(query)
    query_term_ids = [vocabulary.get(token) for token in query_tokens if token in vocabulary]
    
    # Calculate TF-IDF scores for the query
    query_tf_idf = defaultdict(float)
    for term_id in query_term_ids:
        if term_id:
            query_tf_idf[term_id] += 1  # Term Frequency (TF) for the query terms

    # Normalize the query TF-IDF vector
    query_vector_norm = math.sqrt(sum(weight ** 2 for weight in query_tf_idf.values()))
    query_tf_idf = {term_id: weight / (query_vector_norm + 1e-10) for term_id, weight in query_tf_idf.items()}

    # Calculate cosine similarity between query and document vectors
    doc_scores = defaultdict(float)
    for term_id, query_weight in query_tf_idf.items():
        if term_id in inverted_index:
            for doc_id, doc_weight in inverted_index[term_id]:
                doc_scores[doc_id] += query_weight * doc_weight

    # Sort documents by similarity score and select the top-k results
    ranked_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)[:top_k]

    # Retrieve and format the top-k results
    results = []
    for doc_id, score in ranked_docs:
        row = data.iloc[doc_id]
        results.append({
            "restaurantName": row['restaurantName'],
            "address": row['address'],
            "description": row['description'],
            "website": row['website'],
            "similarity": round(score, 4)  # Similarity score should now be in the range [0, 1]
        })

    return pd.DataFrame(results)

# %% [markdown]
# In this cell, we calculate the TF-IDF-based inverted index, which allows us to weight terms by their importance across all restaurant descriptions. We then test our search engine by running a ranked query for "modern seasonal cuisine," retrieving and displaying the top five most relevant restaurant results. This step helps us evaluate the search engine’s effectiveness in returning high-quality, relevant matches based on user input.

# %%
# Calculate the inverted index with TF-IDF weights
inverted_index_tf_idf = calculate_tf_idf(data, vocabulary)

# Perform a ranked query
query = 'modern roman cuisine'
results = ranked_query(query, vocabulary, inverted_index_tf_idf, data, top_k=5)

# Display the results for the query
print(f"Results for the ranked query '{query}':")
results
# Out:
# Results for the ranked query 'modern roman cuisine':
#            restaurantName                  address  \
# 0       Domenico dal 1968           via Satrico 23
# 1  Poldo e Gianna Osteria        vicolo Rosini 6/7
# 2                 CiPASSO        via Metastasio 21
# 3                Roscioli    via dei Giubbonari 21
# 4     Armando al Pantheon  salita de' Crescenzi 31
#
#                                          description  \
# 0  Situated away from the tourist trail, this aut...
# 1  This cheerful and attractive contemporary rest...
# 2  This contemporary bistro with a hint of vintag...
# 3  This restaurant is part of one of the best foo...
# 4  This small restaurant just a few metres from t...
#
#                               website  similarity
# 0     https://www.domenicodal1968.it/      0.2660
# 1          http://www.poldoegianna.it      0.2612
# 2         http://www.cipassoitalia.it      0.2321
# 3  https://www.salumeriaroscioli.com/      0.2001
# 4   https://www.armandoalpantheon.it/      0.1986

# %% [markdown]
# # Question 5

# %%
def create_vocabularies_and_indexes(data):
    vocabularies = {
        'restaurantName': {},
        'city': {},
        'cuisineType': {}
    }
    inverted_indexes = {
        'restaurantName': defaultdict(set),
        'city': defaultdict(set),
        'cuisineType': defaultdict(set)
    }
    term_ids = {
        'restaurantName': 0,
        'city': 0,
        'cuisineType': 0
    }

    # Loop through each restaurant document
    for doc_id, row in data.iterrows():
        for field in ['restaurantName', 'city', 'cuisineType']:
            tokens = preprocess_text(row[field])

            for token in tokens:
                # Assign a new term ID if token not in vocabulary for the field
                if token not in vocabularies[field]:
                    vocabularies[field][token] = term_ids[field]
                    term_ids[field] += 1

                # Add the doc_id to the inverted index for this token in the field
                term_id = vocabularies[field][token]
                inverted_indexes[field][term_id].add(doc_id)

    return vocabularies, inverted_indexes

# %%
def advanced_query(query, vocabularies, inverted_indexes, restaurant_data, filters=None): 
    # Tokenize the query terms for each field in vocabularies
    query_tokens = preprocess_text(query)
    results = set(restaurant_data.index)  # Start with all restaurants as candidates

    # Process query for each field: name, city, cuisine
    for field in ['restaurantName', 'city', 'cuisineType']:
        query_term_ids = [vocabularies[field].get(token) for token in query_tokens if token in vocabularies[field]]
        doc_lists = [inverted_indexes[field][tid] for tid in query_term_ids if tid in inverted_indexes[field]]
        
        # Intersect document lists for the field if terms were found
        if doc_lists:
            results.intersection_update(set.intersection(*doc_lists))

    # Apply filters
    if filters:
        if 'priceRange' in filters:
            results = results.intersection(set(restaurant_data[restaurant_data['priceRange'].isin(filters['priceRange'])].index))

        if 'regions' in filters:
            results = results.intersection(set(restaurant_data[restaurant_data['region'].isin(filters['regions'])].index))
        
        if 'creditCards' in filters:
            # Replace NaN values with empty strings in the 'creditCards' column for safe filtering
            restaurant_data['creditCards'] = restaurant_data['creditCards'].fillna('')
            results = results.intersection(set(
                restaurant_data[restaurant_data['creditCards'].apply(lambda x: any(card in x for card in filters['creditCards']))].index
            ))

        if 'facilities' in filters:
            # Replace NaN values with empty strings in the 'facilitiesServices' column for safe filtering
            restaurant_data['facilitiesServices'] = restaurant_data['facilitiesServices'].fillna('')
            results = results.intersection(set(
                restaurant_data[restaurant_data['facilitiesServices'].apply(lambda x: all(facility in x for facility in filters['facilities']))].index
            ))

    # Extract and format the results
    results_df = restaurant_data.loc[:, ['restaurantName', 'address', 'cuisineType', 'priceRange', 'website']]
    return results_df

# %%
filters = {
    'priceRange': ['€', '€€'],
    'regions': ['Lazio', 'Tuscany'],
    'creditCards': ['Visa', 'MasterCard'],
    'facilities': ['Wi-Fi', 'Terrace']
}
vocabularies = create_vocabularies_and_indexes(df)[0]
inverted_indexes = create_vocabularies_and_indexes(df)[1]
# Run the advanced query
query = 'seafood Italian'
results = advanced_query(query = query, vocabularies = vocabularies, inverted_indexes = inverted_indexes, restaurant_data = df, filters=filters)
print(vocabularies)
inverted_indexes
# Out:
# {'restaurantName': {'20tre': 0, 'alessandro': 1, 'feo': 2, 'ape': 3, 'vino': 4, 'e': 5, 'cucina': 6, 'charleston': 7, 'da': 8, 'bob': 9, 'cook': 10, 'fish': 11, 'dam': 12, 'dama': 13, 'donevandro': 14, 'etra': 15, 'il': 16, 'ristorante': 17, 'alain': 18, 'ducasse': 19, 'napoli': 20, 'tirabusci': 21, 'la': 22, 'buca': 23, 'trattoria': 24, 'enrico': 25, 'bartolini': 26, 'loro': 27, 'mnage': 28, 'mare': 29, 'palazzo': 30, 'utini': 31, 'procaccini': 32, 'sa': 33, 'domu': 34, 'sarda': 35, 'soul': 36, 'bcaro': 37, 'gusto': 38, 'casa': 39, 'rispoli': 40, 'castello': 41, 'di': 42, 'fighine': 43, 'dolada': 44, 'eea': 45, 'gasthofstube': 46, 'stafler': 47, 'luogo': 48, 'aimo': 49, 'nadia': 50, 'niko': 51, 'romito': 52, 'larcangelo': 53, 'brughiera': 54, 'tavola': 55, 'locanda': 56, 'delle': 57, 'tre': 58, 'chiavi': 59, 'luminist': 60, 'caf': 61, 'bistrot': 62, 'musciora': 63, 'osteria': 64, 'le': 65, 'panzanelle': 66, 'mercato': 67, 'quintogusto': 68, 'raie': 69, 'torre': 70, 'del': 71, 'saracino': 72, 'verbano': 73, 'acerorosso': 74, 'paillotes': 75, '4': 76, 'ciance': 77, 'ai': 78, 'mercanti': 79, 'andreina': 80, 'antica': 81, 'rampina': 82, 'magenes': 83, 'santantonio': 84, 'buriani': 85, 'dal': 86, '1967': 87, 'cavour': 88, 'gerry': 89, 'nonna': 90, 'sceppa': 91, 'achilli': 92, 'al': 93, 'parlamento': 94, 'vesta': 95, 'l': 96, 'ciocio': 97, 'suvereto': 98, 'losteria': 99, 'h20': 100, 'magnolia': 101, 'case': 102, 'della': 103, 'saracca': 104, 'afro': 105, 'bagatto': 106, 'vecchio': 107, 'borgo': 108, 'tantris': 109, '50': 110, 'kal': 111, 'alle': 112, 'corone': 113, 'angelo': 114, 'sabatelli': 115, 'format': 116, 'mudec': 117, 'fiorentino': 118, 'giglio': 119, 'foresta': 120, 'hostaria': 121, 'teatro': 122, 'sole': 123, 'ranco': 124, 'barca': 125, 'fossa': 126, 'grano': 127, 'rosina': 128, 'laite': 129, 'calandre': 130, 'cuochi': 131, 'menzaghi': 132, 'miculan': 133, 'villetta': 134, 'annessa': 135, 'noci': 136, 'volt': 137, 'ansitz': 138, 'steinbock': 139, 'apollinare': 140, 'pievano': 141, 'j': 142, 'contemporary': 143, 'japanese': 144, 'restaurant': 145, 'pajara': 146, 'gourmet': 147, 'tradizione': 148, 'casalinga': 149, 'lo': 150, 'scudiero': 151, 'malga': 152, 'roncac': 153, 'morelli': 154, 'olona': 155, 'venanzio': 156, '1922': 157, 'arbustico': 158, 'arborina': 159, 'sandira': 160, 'salvo': 161, 'cacciatori': 162, 'olivi': 163, 'un': 164, 'posto': 165, 'milano': 166, 'agli': 167, 'amici': 168, 'monte': 169, 'rosso': 170, 'danielcanzian': 171, 'baccofurore': 172, 'buco': 173, 'convito': 174, 'curina': 175, 'santo': 176, 'bevitore': 177, 'ilario': 178, 'vinciguerra': 179, 'radici': 180, 'nni': 181, 'lausta': 182, 'onda': 183, 'blu': 184, 'de': 185, 'brg': 186, 'lorciaia': 187, 'posta': 188, 'san': 189, 'martino': 190, 'st': 191, 'george': 192, 'heinz': 193, 'beck': 194, 'terrazza': 195, 'bosquet': 196, 'trequarti': 197, 'cavallino': 198, 'bianco': 199, 'atelier': 200, 'vallagarina': 201, 'giacomo': 202, 'belbo': 203, 'bardon': 204, 'el': 205, 'fil': 206, 'entr': 207, 'filippino': 208, 'galeone': 209, 'loste': 210, 'sacrestano': 211, 'grotta': 212, '1918': 213, 'piero': 214, 'marcelin': 215, 'moscatello': 216, 'muliner': 217, 'papaveri': 218, 'papere': 219, 'regina': 220, 'lucia': 221, 'losanna': 222, 'trippi': 223, 'vespasia': 224, 'angiolina': 225, 'bite': 226, 'ca': 227, 'moro': 228, 'controcorrente': 229, 'banchi': 230, 'due': 231, 'buoi': 232, 'fenicottero': 233, 'rosa': 234, 'fico': 235, 'trentacareghe': 236, 'luva': 237, 'malto': 238, 'taverna': 239, 'cialoma': 240, 'sosta': 241, 'ottone': 242, 'iii': 243, 'leone': 244, 'baccanti': 245, 'rune': 246, 'li': 247, 'lioni': 248, 'maso': 249, 'burba': 250, 'fontanina': 251, 'viva': 252, 'cuoco': 253, 'bordo': 254, 'bolle': 255, 'contrasto': 256, 'futura': 257, 'colonne': 258, 'serafino': 259, 'menarosti': 260, 'nives': 261, 'oberlechner': 262, 'chiocciola': 263, 'solita': 264, 'zuppa': 265, 'numero': 266, '2': 267, 'zanchetti': 268, 'portanova': 269, 'ratan': 270, 'saur': 271,  ...
# {'restaurantName': defaultdict(set,
#              {0: {0},
#               1: {1, 184},
#               2: {1},
#               3: {2},
#               4: {2, 124, 597, 729, 781, 1115, 1192},
#               5: {2,
#                26,
#                68,
#                131,
#                137,
#                150,
#                250,
#                382,
#                455,
#                479,
#                523,
#                549,
#                597,
#                685,
#                729,
#                817,
#                820,
#                890,
#                945,
#                958,
#                994,
#                1019,
#                1063,
#                1115,
#                1156,
#                1192,
#                1222,
#                1281,
#                1570,
#                1614,
#                1677,
#                1678,
#                1784,
#                1836,
#                1976},
#               6: {2,
#                91,
#                204,
#                256,
#                287,
#                528,
#                597,
#                729,
#                749,
#                809,
#                1047,
#                1115,
#                1156,
#                1192,
#                1222,
#                1255,
#                1271,
#                1313,
#                1525,
#                1677,
#                1923},
#               7: {3},
#               8: {4,
#                50,
#                51,
#                58,
#                80,
#                95,
#                104,
#                125,
#                126,
#                245,
#                253,
#                267,
#                268,
#                288,
#                289,
#                295,
#                310,
#                311,
#                312,
#                331,
#                347,
#                468,
#                469,
#                508,
#                510,
#                547,
#                560,
#                566,
#                588,
#                623,
#                624,
#                625,
#                640,
#                648,
#                667,
#                685,
#                686,
#                759,
#                766,
#                767,
#                804,
#                810,
#                845,
#                929,
#                937,
#                968,
#                969,
#                970,
#                1081,
#                1129,
#                1149,
#                1165,
#                1201,
#                1307,
#                1308,
#                1321,
#                1329,
#                1384,
#                1385,
#                1439,
#                1447,
#                1469,
#                1486,
#                1498,
#                1520,
#                1528,
#                1547,
#                1554,
#                1646,
#                1660,
#                1665,
#                1682,
#                1706,
#                1781,
#                1788,
#                1804,
#                1829,
#                1839,
#                1853,
#                1876,
#                1885,
#                1905,
#                1927,
#                1937},
#               9: {4},
#               10: {4, 1080},
#               11: {4, 19, 883},
#               12: {5},
#               13: {6, 425},
#               14: {7},
#               15: {8},
#               16: {9,
#                10,
#                15,
#                20,
#                26,
#                27,
#                59,
#                72,
#                87,
#                103,
#                107,
#                108,
#                109,
#                130,
#                131,
#                148,
#                149,
#                150,
#                161,
#                191,
#                209,
#                249,
#                250,
#                251,
#                252,
#                269,
#                292,
#                293,
#                314,
#                330,
#                331,
#                332,
#                333,
#                334,
#                369,
#                370,
#                452,
#                453,
#                454,
#                499,
#                510,
#                552,
#                590,
#                607,
#                627,
#                628,
#                629,
#                630,
#                650,
#                651,
#                675,
#                676,
#                689,
#                709,
#                721,
#                732,
#                742,
#                771,
#                776,
#                790,
#                791,
#                807,
#                817,
#                830,
#                893,
#                910,
#                911,
#                912,
#                948,
#                1008,
#                1023,
#                1067,
#                1069,
#                1090,
#                1112,
#                1113,
#                1129,
#                1131,
#                1132,
#                1133,
#                1134,
#                1151,
#                1177,
#                1185,
#                1186,
#                1194,
#                1213,
#                1214,
#                1215,
#                1229,
#                1230,
#                1265,
#                1266,
#                1273,
#                1289,
#                1290,
#                1291,
#                1311,
#                1329,
#                1350,
#                1351,
#                1369,
#                1388,
#                1409,
#                1429,
#                1447,
#                1448,
#                1454,
#                1472,
#                1488,
#                1489,
#                1503,
#                1516,
#                1549,
#                1550,
#                1557,
#                1608,
#                1653,
#                1670,
#                1688,
#                1689,
#                1708,
#                1709,
#                1710,
#                1729,
#                1749,
#                1750,
#                1770,
#                1793,
#                1794,
#                1805,
#                1806,
#                1807,
#                1815,
#                1844,
#                1910,
#                1911,
#                1950},
#               17: {9,
#                27,
#                189,
#                267,
#                285,
#                448,
#                497,
#                510,
#                545,
#                651,
#                728,
#                762,
#                1005,
#                1049,
#                1058,
#                1075,
#                1485,
#                1495,
#                1594,
#                1602,
#                1702,
#                1723,
#                1725,
#                1827,
#                1883,
#                1922,
#                1954,
#                1964,
#                1969},
#               18: {9},
#               19: {9},
#               20: {9},
#               21: {10},
#               22: {11,
#                12,
#                29,
#                30,
#                45,
#                56,
#                73,
#                74,
#                75,
#                89,
#                90,
#                91,
#                132,
#                133,
#                151,
#                152,
#                153,
#                154,
#                160,
#                173,
#                197,
#                211,
#                212,
#                213,
#                255,
#                256,
#                271,
#                297,
#                298,
#                336,
#                337,
#                354,
#                355,
#                356,
#                372,
#                373,
#                389,
#                390,
#                409,
#                410,
#                415,
#                416,
#                429,
#                430,
#                438,
#                461,
#                463,
#                474,
#                475,
#                476,
#                488,
#                489,
#                497,
#                512,
#                513,
#                530,
#                531,
#                545,
#                553,
#                554,
#                572,
#                593,
#                594,
#                595,
#                610,
#                611,
#                612,
#                613,
#                631,
#                632,
#                652,
#                653,
#                677,
#                691,
#                692,
#                693,
#                694,
#                710,
#                711,
#                712,
#                713,
#                751,
#                752,
#                773,
#                793,
#                794,
#                795,
#                809,
#                831,
#                854,
#                894,
#                914,
#                934,
#                950,
#                951,
#                952,
#                977,
#                978,
#                979,
#                987,
#                1010,
#                1028,
#                1029,
#                1051,
#                1052,
#                1053,
#                1070,
#                1092,
#                1093,
#                1111,
#                1114,
#                1152,
#                1172,
#                1173,
#                1174,
#                1189,
#                1211,
#                1218,
#                1231,
#                1253,
#                1268,
#                1269,
#                1294,
#                1313,
#                1314,
#                1315,
#                1332,
#                1333,
#                1371,
#                1372,
#                1390,
#                1391,
#                1405,
#                1410,
#                1411,
#                1431,
#                1449,
#                1450,
#                1474,
#                1475,
#                1476,
#                1490,
#                1491,
#                1499,
#                1510,
#                1532,
#                1533,
#                1570,
#                1632,
#                1651,
#                1652,
#                1655,
#                1672,
#                1673,
#                1674,
#                1693,
#                1694,
#                1700,
#                1722,
#                1732,
#                1753,
#                1754,
#                1773,
#                1795,
#                1796,
#                1803,
#                1809,
#                1810,
#                1846,
#                1889,
#                1890,
#                1891,
#                1936,
#                1952},
#               23: {11, 47, 1164},
#               24: {12,
#                80,
#                132,
#                139,
#                218,
#                219,
#                222,
#                260,
#                261,
#                264,
#                281,
#                284,
#                379,
#                401,
#                421,
#                461,
#                463,
#                520,
#                559,
#                560,
#                561,
#                578,
#                616,
#                617,
#                618,
#                660,
#                662,
#                721,
#                759,
#                800,
#                863,
#                864,
#                913,
#                1061,
#                1081,
#                1141,
#                1260,
#                1262,
#                1339,
#                1360,
#                1379,
#                1419,
#                1439,
#                1440,
#                1441,
#                1459,
#                1479,
#                1498,
#                1499,
#                1518,
#                1558,
#                1601,
#                1660,
#                1681,
#                1700,
#                1741,
#                1760,
#                1761,
#                1781,
#                1901},
#               25: {12, 67, 811, 1606},
#               26: {12, 67, 811, 1606, 1714, 1757, 1838, 1860},
#               27: {13},
#               28: {14},
#               29: {15,
#                53,
#                410,
#                600,
#                827,
#                1036,
#                1095,
#                1108,
#                1382,
#                1423,
#                1516,
#                1678,
#                1920},
#               30: {16, 83, 799, 1098, 1318},
#               31: {16},
#               32: {17},
#               33: {18, 339, 598, 779, 1976},
#               34: {18},
#               35: {18},
#               36: {19},
#               37: {20},
#               38: {20, 290, 675, 893, 1531, 1718},
#               39: {21,
#                65,
#                124,
#                646,
#                665,
#                724,
#                783,
#                906,
#                1045,
#                1245,
#                1246,
#                1282,
#                1283,
#                1325,
#                1364,
#                1426,
#                1567,
#                1585,
#                1704,
#                1724,
#                1753,
#                1786,
#                1859,
#                1886},
#               40: {21},
#               41: {22, 66, 184, 1699, 1867},
#               42: {22,
#                47,
#                54,
#                72,
#                108,
#                133,
#                152,
#                163,
#                180,
#                183,
#                184,
#                188,
#                256,
#                316,
#                473,
#                510,
#                578,
#                631,
#                652,
#                653,
#                658,
#                823,
#                825,
#                886,
#                893,
#                922,
#                939,
#                957,
#                977,
#                1071,
#                1132,
#                1141,
#                1151,
#                1164,
#                1224,
#                1240,
#                1263,
#                1287,
#                1309,
#                1329,
#                1378,
#                1391,
#                1423,
#                1429,
#                1431,
#                1441,
#                1449,
#                1535,
#                1570,
#                1615,
#                1650,
#                1678,
#                1799,
#                1843,
#                1858,
#                1866,
#                1879,
#                1886,
#                1889},
#               43: {22},
#               44: {23},
#               45: {24},
#               46: {25},
#               47: {25},
#               48: {26},
#               49: {26, 382, 1281},
#               50: {26, 104, 382, 1281},
#               51: {27, 651},
#               52: {27, 651},
#               53: {28},
#               54: {29, 719},
#               55: {30, 316, 1391},
#               56: {31,
#                68,
#                78,
#                89,
#                111,
#                133,
#                168,
#                194,
#                231,
#                357,
#                391,
#                433,
#                458,
#                491,
#                522,
#                531,
#                535,
#                633,
#                655,
#                697,
#                744,
#                810,
#                811,
#                812,
#                854,
#                855,
#                897,
#                922,
#                936,
#                951,
#                980,
#                1010,
#                1071,
#                1093,
#                1095,
#                1114,
#                1122,
#                1175,
#                1231,
#                1232,
#                1270,
#                1295,
#                1296,
#                1323,
#                1413,
#                1492,
#                1511,
#                1512,
#                1534,
#                1535,
#                1536,
#                1553,
#                1570,
#                1610,
#                1694,
#                1733,
#                1755,
#                1811,
#                1812,
#                1851,
#                1873,
#                1889,
#                1893,
#                1894,
#                1924,
#                1931,
#                1970},
#               57: {31, 267, 1168, 1175, 1468, 1708},
#               58: {31, 82, 100, 579, 739, 767, 896, 913, 1580},
#               59: {31, 1872},
#               60: {32},
#               61: {32, 41, 1244, 1645},
#               62: {32,
#                161,
#                189,
#                346,
#                439,
#                444,
#                504,
#                564,
#                584,
#                664,
#                745,
#                924,
#                1042,
#                1148,
#                1187,
#                1258,
#                1405,
#                1408,
#                1468,
#                1537,
#                1582,
#                1592,
#                1633,
#                1642,
#                1791},
#               63: {33},
#               64: {34,
#                35,
#                45,
#                46,
#                54,
#                58,
#                59,
#                60,
#                96,
#                97,
#                103,
#                114,
#                115,
#                116,
#                159,
#                160,
#                172,
#                173,
#                174,
#                175,
#                195,
#                236,
#                237,
#                262,
#                273,
#                274,
#                275,
#                296,
#                299,
#                318,
#                323,
#                393,
#                394,
#                414,
#                415,
#                416,
#                437,
#                438,
#                479,
#                495,
#                514,
#                515,
#                556,
#                571,
#                592,
#                633,
#                643,
#                657,
#                698,
#                718,
#                719,
#                735,
#                775,
#                815,
#                816,
#                817,
#                836,
#                884,
#                901,
#                910,
#                916,
#                918,
#                929,
#                937,
#                938,
#                942,
#                955,
#                956,
#                957,
#                991,
#                992,
#                993,
#                994,
#                1015,
#                1016,
#                1023,
#                1035,
#                1057,
#                1073,
#                1074,
#                1097,
#                1177,
#                1194,
#                1202,
#                1206,
#                1257,
#                1265,
#                1272,
#                1273,
#                1274,
#                1299,
#                1317,
#                1342,
#                1344,
#                1376,
#                1382,
#                1396,
#                1397,
#                1404,
#                1415,
#                1424,
#                1433,
#                1434,
#                1435,
#                1436,
#                1453,
#                1515,
#                1516,
#                1540,
#                1554,
#                1576,
#                1597,
#                1613,
#                1655,
#                1656,
#                1682,
#                1696,
#                1712,
#                1713,
#                1714,
#                1715,
#                1736,
#                1737,
#                1747,
#                1757,
#                1776,
#                1777,
#                1797,
#                1814,
#                1815,
#                1828,
#                1838,
#                1839,
#                1846,
#                1853,
#                1854,
#                1876,
#                1877,
#                1878,
#                1914,
#                1936,
#                1957,
#                1958,
#                1973},
#               65: {34,
#                41,
#                57,
#                77,
#                155,
#                156,
#                167,
#                431,
#                432,
#                437,
#                533,
#                634,
#                695,
#                753,
#                832,
#                885,
#                896,
#                915,
#                935,
#                989,
#                1011,
#                1030,
#                1031,
#                1136,
#                1334,
#                1412,
#                1432,
#                1571,
#                1592,
#                1634,
#                1715,
#                1849,
#                1872,
#                1913},
#               66: {34},
#               67: {35, 910, 1265},
#               68: {36},
#               69: {37},
#               70: {38, 154, 476, 831, 1053, 1211, 1655},
#               71: {38,
#                68,
#                71,
#                74,
#                89,
#                115,
#                124,
#                126,
#                144,
#                153,
#                198,
#                226,
#                236,
#                262,
#                264,
#                269,
#                281,
#                318,
#                378,
#                392,
#                410,
#                421,
#                424,
#                433,
#                441,
#                451,
#                477,
#                491,
#                506,
#                514,
#                531,
#                606,
#                633,
#                660,
#                669,
#                673,
#                675,
#                708,
#                724,
#                744,
#                775,
#                951,
#                965,
#                989,
#                993,
#                994,
#                1010,
#                1035,
#                1038,
#                1104,
#                1171,
#                1288,
#                1317,
#                1332,
#                1367,
#                1381,
#                1382,
#                1418,
#                1440,
#                1465,
#                1474,
#                1516,
#                1554,
#                1671,
#                1674,
#                1694,
#                1699,
#                1718,
#                1725,
#                1733,
#                1736,
#                1755,
#                1761,
#                1768,
#                1777,
#                1814,
#                1849,
#                1851,
#                1854,
#                1873,
#                1899,
#                1916},
#               72: {38},
#               73: {39},
#               74: {40},
#               75: {41},
#               76: {42, 78},
#               77: {42},
#               78: {43, 218, 231, 302, 403, 767, 823, 1504, 1542, 1582, 1882},
#               79: {43},
#               80: {44},
#               81: {45,
#                46,
#                80,
#                103,
#                132,
#                262,
#                263,
#                264,
#                284,
#                323,
#                463,
#                522,
#                643,
#                662,
#                744,
#                785,
#                863,
#                864,
#                903,
#                922,
#                942,
#                1023,
#                1122,
#                1146,
#                1262,
#                1382,
#                1404,
#                1424,
#                1442,
#                1465,
#                1482,
#                1505,
#                1510,
#                1682,
#                1923,
#                1924},
#               82: {45},
#               83: {46},
#               84: {47},
#               85: {48},
#               86: {48, 95, 132, 273, 567, 973, 1088, 1092, 1440, 1666},
#               87: {48},
#               88: {49, 184},
#               89: {50},
#               90: {51, 323, 1535},
#               91: {51},
#               92: {52},
#               93: {52,
#                67,
#                83,
#                84,
#                122,
#                162,
#                182,
#                184,
#                219,
#                303,
#                343,
#                364,
#                365,
#                404,
#                462,
#                520,
#                522,
#                533,
#                542,
#                543,
#                563,
#                601,
#                602,
#                682,
#                685,
#                743,
#                783,
#                800,
#                824,
#                825,
#                962,
#                1002,
#                1095,
#                1116,
#                1134,
#                1144,
#                1169,
#                1222,
#                1247,
#                1262,
#                1303,
#                1320,
#                1379,
#                1402,
#                1403,
#                1419,
#                1453,
#                1462,
#                1479,
#                1543,
#                1563,
#                1598,
#                1622,
#                1623,
#                1662,
#                1700,
#                1729,
#                1788,
#                1822,
#                1823,
#                1944},
#               94: {52},
#               95: {53},
#               96: {54, 216},
#               97: {54},
#               98: {54},
#               99: {55, 192, 473, 1193, 1671},
#               100: {55},
#               101: {56, 1875},
#               102: {57},
#               103: {57,
#                124,
#                172,
#                260,
#                296,
#                543,
#                698,
#                719,
#                948,
#                986,
#                994,
#                1061,
#                1074,
#                1193,
#                1295,
#                1435,
#                1585,
#                1662},
#               104: {57},
#               105: {58},
#               106: {59, 162, 406},
#               107: {60, 701, 1002, 1231, 1329, 1479, 1500},
#               108: {60, 89, 115, 187, 585, 816, 1622, 1664, 1849, 1962},
#               109: {61},
#               110: {62},
#               111: {62},
#               112: {63, 955, 1105, 1286, 1464},
#               113: {63},
#               114: {64},
#               115: {64},
#               116: {65},
#               117: {67},
#               118: {68},
#               119: {68, 70},
#               120: {69, 672},
#               121: {71,
#                106,
#                248,
#                329,
#                451,
#                750,
#                1110,
#                1147,
#                1287,
#                1367,
#                1368,
#                1728,
#                1804},
#               122: {71, 236, 685},
#               123: {72},
#               124: {72},
#               125: {73, 1253},
#               126: {74},
#               127: {74, 886, 1429},
#               128: {75},
#               129: {76},
#               130: {77},
#               131: {78},
#               132: {79},
#               133: {80},
#               134: {81, 698},
#               135: {81},
#               136: {82},
#               137: {84},
#               138: {85, 518},
#               139: {85},
#               140: {86},
#               141: {87},
#               142: {88},
#               143: {88, 1790},
#               144: {88, 961},
#               145: {88,
#                135,
#                238,
#                241,
#                272,
#                352,
#                425,
#                449,
#                450,
#                596,
#                609,
#                644,
#                647,
#                733,
#                803,
#                833,
#                847,
#                849,
#                877,
#                919,
#                952,
#                966,
#                1004,
#                1041,
#                1078,
#                1085,
#                1161,
#                1184,
#                1212,
#                1246,
#                1268,
#                1300,
#                1349,
#                1387,
#                1587,
#                1637,
#                1672,
#                1692,
#                1727,
#                1746,
#                1779,
#                1780,
#                1782,
#                1790,
#                1947,
#                1980},
#               146: {90},
#               147: {90, 148, 298, 544, 553, 645, 1058, 1390, 1450, 1551, 1921},
#               148: {91},
#               149: {91},
#               150: {92, 654, 714, 847, 897, 1138},
#               151: {92},
#               152: {93, 754},
#               153: {93},
#               154: {94, 938, 1637},
#               155: {95},
#               156: {95},
#               157: {95},
#               158: {96},
#               159: {97},
#               160: {98},
#               161: {99, 239},
#               162: {99, 697, 706, 1467},
#               163: {100},
#               164: {101, 1960},
#               165: {101, 1736},
#               166: {101, 501, 1014, 1052, 1304, 1801},
#               167: {102, 471},
#               168: {102, 471},
#               169: {103},
#               170: {103, 722, 1347, 1454, 1858},
#               171: {105},
#               172: {106},
#               173: {107},
#               174: {108, 948},
#               175: {108},
#               176: {109, 1365},
#               177: {109},
#               178: {110},
#               179: {110},
#               180: {111, 880, 918, 1059, 1398},
#               181: {112},
#               182: {112},
#               183: {113},
#               184: {113, 378, 496, 1314},
#               185: {114,
#                216,
#                221,
#                584,
#                687,
#                731,
#                914,
#                1208,
#                1209,
#                1313,
#                1381,
#                1396,
#                1526,
#                1610,
#                1713,
#                1891,
#                1964},
#               186: {114},
#               187: {116},
#               188: {117, 260, 1269, 1855},
#               189: {118,
#                187,
#                278,
#                313,
#                397,
#                460,
#                481,
#                881,
#                900,
#                1007,
#                1018,
#                1100,
#                1232,
#                1248,
#                1455,
#                1512,
#                1525,
#                1553,
#                1577,
#                1617,
#                1658,
#                1696,
#                1840,
#                1866},
#               190: {118, 188, 731, 1100, 1232, 1658},
#               191: {119, 1788},
#               192: {119, 1947},
#               193: {119},
#               194: {119},
#               195: {120,
#                217,
#                271,
#                400,
#                613,
#                841,
#                1241,
#                1579,
#                1673,
#                1803,
#                1860},
#               196: {120},
#               197: {121},
#               198: {122, 666, 1027, 1503},
#               199: {122},
#               200: {123, 465},
#               201: {124},
#               202: {125},
#               203: {126},
#               204: {126},
#               205: {127, 328, 902, 1309, 1668, 1908},
#               206: {127},
#               207: {128},
#               208: {129},
#               209: {130},
#               210: {131, 335, 353},
#               211: {131},
#               212: {132},
#               213: {132},
#               214: {133},
#               215: {134},
#               216: {136},
#               217: {136},
#               218: {137},
#               219: {137},
#               220: {138},
#               221: {138, 1084, 1393},
#               222: {139},
#               223: {140},
#               224: {141},
#               225: {142},
#               226: {143},
#               227: {144, 306, 586, 645, 965, 983, 1125, 1842},
#               228: {144, 273, 1280, 1623, 1709, 1815},
#               229: {145, 507},
#               230: {146},
#               231: {147, 208, 218, 437, 562, 605, 832, 973, 1907},
#               232: {147},
#               233: {148},
#               234: {148, 323, 461, 889, 979, 1775},
#               235: {149},
#               236: {149},
#               237: {150},
#               238: {150},
#               239: {151,
#                153,
#                360,
#                378,
#                653,
#                659,
#                680,
#                738,
#                840,
#                998,
#                1038,
#                1239,
#                1431,
#                1458,
#                1520,
#                1699},
#               240: {151},
#               241: {152, 1890},
#               242: {152},
#               243: {152},
#               244: {153},
#               245: {155, 683},
#               246: {156},
#               247: {157, 193, 1190, 1635},
#               248: {157},
#               249: {158, 876, 954},
#               250: {158},
#               251: {160},
#               252: {161},
#               253: {163},
#               254: {163},
#               255: {164},
#               256: {165},
#               257: {166, 1747},
#               258: {167, 527, 1432},
#               259: {168},
#               260: {169},
#               261: {170},
#               262: {171},
#               263: {172, 554},
#               264: {173},
#               265: {173},
#               266: {174, 556},
#               267: {174},
#               268: {175},
#               269: {176},
#               270: {177},
#               271: {178},
#               272: {179},
#               273: {180},
#               274: {180},
#               275: {181},
#               276: {181},
#               277: {182},
#               278: {183},
#               279: {183},
#               280: {184},
#               281: {184},
#               282: {185},
#               283: {186, 1644},
#               284: {186},
#               285: {187},
#               286: {188},
#               287: {188},
#               288: {188},
#               289: {188, 663, 1627},
#               290: {189},
#               291: {190},
#               292: {191, 1291},
#               293: {192},
#               294: {193},
#               295: {194},
#               296: {195, 201, 619, 960, 1221},
#               297: {195},
#               298: {196},
#               299: {197},
#               300: {197,
#                274,
#                360,
#                488,
#                655,
#                706,
#                806,
#                809,
#                891,
#                933,
#                946,
#                956,
#                959,
#                979,
#                1008,
#                1093,
#                1114,
#                1415,
#                1424,
#                1534,
#                1597},
#               301: {197},
#               302: {198},
#               303: {198, 671, 1897, 1928},
#               304: {199},
#               305: {200},
#               306: {201},
#               307: {202, 285, 982, 992, 1883},
#               308: {202},
#               309: {203},
#               310: {205},
#               311: {206},
#               312: {207},
#               313: {207},
#               314: {208},
#               315: {209},
#               316: {210},
#               317: {211},
#               318: {212,
#                296,
#                423,
#                474,
#                587,
#                604,
#                779,
#                785,
#                1180,
#                1327,
#                1328,
#                1390},
#               319: {213},
#               320: {213},
#               321: {213},
#               322: {213},
#               323: {214},
#               324: {215, 552},
#               325: {216, 298, 1074},
#               326: {216},
#               327: {217},
#               328: {218},
#               329: {219},
#               330: {220},
#               331: {221,
#                240,
#                521,
#                601,
#                609,
#                620,
#                661,
#                677,
#                741,
#                760,
#                1001,
#                1076,
#                1101,
#                1501,
#                1541,
#                1721,
#                1821,
#                1939,
#                1940,
#                1961},
#               332: {221},
#               333: {222},
#               334: {223},
#               335: {224},
#               336: {225},
#               337: {226},
#               338: {226},
#               339: {227, 1591},
#               340: {227},
#               341: {228},
#               342: {229},
#               343: {230},
#               344: {231, 391, 665, 1095},
#               345: {231},
#               346: {232},
#               347: {233},
#               348: {234},
#               349: {235, 1316},
#               350: {235},
#               351: {237},
#               352: {238},
#               353: {238},
#               354: {240},
#               355: {240},
#               356: {241},
#               357: {242, 1360},
#               358: {243},
#               359: {243},
#               360: {244},
#               361: {244, 338, 1391},
#               362: {245, 631},
#               363: {246},
#               364: {247},
#               365: {247},
#               366: {248,
#                423,
#                559,
#                583,
#                616,
#                802,
#                927,
#                1180,
#                1322,
#                1323,
#                1522,
#                1797,
#                1902,
#                1905,
#                1937},
#               367: {248},
#               368: {249},
#               369: {250},
#               370: {250},
#               371: {250},
#               372: {250, 1893},
#               373: {251},
#               374: {252},
#               375: {253},
#               376: {254},
#               377: {255},
#               378: {256, 898},
#               379: {256},
#               380: {257},
#               381: {258},
#               382: {259},
#               383: {261},
#               384: {262, 480, 800},
#               385: {263},
#               386: {264, 709, 892, 994, 1262, 1418},
#               387: {265},
#               388: {266, 1003},
#               389: {267},
#               390: {267, 1586},
#               391: {267},
#               392: {267},
#               393: {268},
#               394: {269, 1401},
#               395: {269},
#               396: {270},
#               397: {270},
#               398: {272},
#               399: {274},
#               400: {275},
#               401: {276, 1817},
#               402: {277},
#               403: {278, 289, 1381, 1512},
#               404: {279},
#               405: {280},
#               406: {281, 1115, 1608},
#               407: {281, 1039},
#               408: {282},
#               409: {283},
#               410: {284},
#               411: {285},
#               412: {286},
#               413: {287},
#               414: {287},
#               415: {288},
#               416: {289},
#               417: {289, 1098},
#               418: {290},
#               419: {291},
#               420: {291, 1719},
#               421: {292},
#               422: {293},
#               423: {294},
#               424: {295},
#               425: {295, 348},
#               426: {297, 914, 1166, 1450},
#               427: {297},
#               428: {299},
#               429: {300, 1518},
#               430: {300},
#               431: {300},
#               432: {301},
#               433: {302},
#               434: {303},
#               435: {304, 310, 1071, 1223, 1603, 1843},
#               436: {304, 717, 1339, 1824},
#               437: {304},
#               438: {305},
#               439: {305, 1083},
#               440: {306, 1328},
#               441: {307},
#               442: {308},
#               443: {309},
#               444: {309},
#               445: {311, 1665},
#               446: {312, 413},
#               447: {313, 426, 606, 1211, 1263, 1771, 1789, 1886},
#               448: {313},
#               449: {314},
#               450: {315},
#               451: {316, 508, 510, 1130},
#               452: {317},
#               453: {318},
#               454: {319, 818, 990, 1972},
#               455: {320, 407, 473, 860},
#               456: {320, 780},
#               457: {321},
#               458: {322},
#               459: {324},
#               460: {325},
#               461: {325},
#               462: {326, 1063},
#               463: {327},
#               464: {328},
#               465: {329},
#               466: {329},
#               467: {330},
#               468: {331},
#               469: {331},
#               470: {332, 777},
#               471: {333},
#               472: {334},
#               473: {334},
#               474: {335, 977, 1868},
#               475: {336},
#               476: {337},
#               477: {338, 455, 1123, 1295, 1626},
#               478: {339},
#               479: {340},
#               480: {341},
#               481: {342},
#               482: {343},
#               483: {344},
#               484: {345},
#               485: {346},
#               486: {347, 1469},
#               487: {349},
#               488: {350, 1389},
#               489: {350},
#               490: {351},
#               491: {352},
#               492: {352},
#               493: {353, 1654},
#               494: {354, 1593},
#               495: {355},
#               496: {356},
#               497: {357},
#               498: {358},
#               499: {358},
#               500: {359},
#               501: {360},
#               502: {361},
#               503: {361, 446, 769, 1717},
#               504: {361},
#               505: {362, 724},
#               506: {362},
#               507: {363},
#               508: {363, 1362},
#               509: {364},
#               510: {365},
#               511: {366, 721},
#               512: {367},
#               513: {368},
#               514: {369},
#               515: {370, 1438},
#               516: {371},
#               517: {372, 572, 1173},
#               518: {373, 1441},
#               519: {374},
#               520: {375, 1900},
#               521: {375, 1544},
#               522: {376},
#               523: {377, 700, 1536},
#               524: {378, 805},
#               525: {379, 820},
#               526: {380},
#               527: {381},
#               528: {381},
#               529: {382},
#               530: {383},
#               531: {384, 1960},
#               532: {385},
#               533: {386},
#               534: {387, 556},
#               535: {387},
#               536: {388},
#               537: {389},
#               538: {390},
#               539: {392, 473, 774, 1221, 1695},
#               540: {392},
#               541: {393},
#               542: {393, 1517},
#               543: {394},
#               544: {395},
#               545: {395},
#               546: {396, 1677},
#               547: {397, 1377, 1519},
#               548: {397},
#               549: {398},
#               550: {399},
#               551: {399},
#               552: {400},
#               553: {401},
#               554: {402},
#               555: {403},
#               556: {404},
#               557: {405},
#               558: {405,
#                430,
#                575,
#                681,
#                711,
#                805,
#                1436,
#                1536,
#                1572,
#                1820,
#                1872},
#               559: {407},
#               560: {407},
#               561: {408},
#               562: {409, 1490},
#               563: {410, 794, 1405},
#               564: {411},
#               565: {412},
#               566: {414},
#               567: {415},
#               568: {416, 490, 1322, 1905},
#               569: {417},
#               570: {418, 1078},
#               571: {418},
#               572: {418},
#               573: {419},
#               574: {420},
#               575: {421, 1745},
#               576: {422},
#               577: {422, 565},
#               578: {422, 1389, 1560, 1968},
#               579: {423},
#               580: {424},
#               581: {424},
#               582: {426},
#               583: {427},
#               584: {428},
#               585: {429},
#               586: {430, 575, 1632},
#               587: {431},
#               588: {432},
#               589: {433},
#               590: {434},
#               591: {435},
#               592: {436},
#               593: {436},
#               594: {437},
#               595: {438},
#               596: {439},
#               597: {440},
#               598: {441},
#               599: {441},
#               600: {442},
#               601: {443, 882},
#               602: {443, 1539},
#               603: {444, 1324},
#               604: {445},
#               605: {446},
#               606: {446, 1717},
#               607: {447},
#               608: {448},
#               609: {449},
#               610: {450},
#               611: {451, 1710},
#               612: {452},
#               613: {453},
# ...
#                116,
#                122,
#                126,
#                142,
#                150,
#                151,
#                154,
#                167,
#                173,
#                211,
#                218,
#                236,
#                246,
#                248,
#                255,
#                257,
#                299,
#                300,
#                302,
#                303,
#                327,
#                331,
#                346,
#                369,
#                372,
#                377,
#                397,
#                401,
#                403,
#                405,
#                415,
#                416,
#                433,
#                434,
#                438,
#                454,
#                464,
#                468,
#                469,
#                478,
#                479,
#                481,
#                487,
#                489,
#                498,
#                505,
#                511,
#                522,
#                540,
#                542,
#                548,
#                552,
#                559,
#                560,
#                561,
#                566,
#                571,
#                578,
#                585,
#                593,
#                598,
#                603,
#                607,
#                617,
#                621,
#                623,
#                633,
#                674,
#                677,
#                678,
#                679,
#                695,
#                698,
#                706,
#                714,
#                718,
#                720,
#                721,
#                732,
#                738,
#                746,
#                751,
#                772,
#                779,
#                781,
#                787,
#                789,
#                791,
#                792,
#                802,
#                805,
#                810,
#                817,
#                830,
#                832,
#                845,
#                856,
#                880,
#                887,
#                889,
#                895,
#                933,
#                969,
#                990,
#                1008,
#                1010,
#                1025,
#                1036,
#                1063,
#                1074,
#                1093,
#                1122,
#                1126,
#                1131,
#                1137,
#                1173,
#                1193,
#                1201,
#                1220,
#                1226,
#                1231,
#                1259,
#                1269,
#                1287,
#                1292,
#                1309,
#                1316,
#                1339,
#                1360,
#                1363,
#                1383,
#                1395,
#                1415,
#                1440,
#                1447,
#                1453,
#                1460,
#                1466,
#                1473,
#                1474,
#                1476,
#                1479,
#                1481,
#                1520,
#                1546,
#                1558,
#                1559,
#                1569,
#                1576,
#                1594,
#                1622,
#                1635,
#                1654,
#                1664,
#                1665,
#                1688,
#                1700,
#                1709,
#                1719,
#                1733,
#                1737,
#                1742,
#                1747,
#                1751,
#                1761,
#                1766,
#                1774,
#                1776,
#                1781,
#                1811,
#                1814,
#                1820,
#                1841,
#                1845,
#                1846,
#                1853,
#                1855,
#                1863,
#                1874,
#                1876,
#                1877,
#                1884,
#                1885,
#                1903,
#                1905,
#                1927,
#                1941},
#               21: {28, 263, 479, 567, 805, 910, 944, 1218, 1247, 1437, 1818},
#               22: {29,
#                45,
#                125,
#                140,
#                246,
#                264,
#                281,
#                423,
#                588,
#                662,
#                698,
#                781,
#                845,
#                886,
#                923,
#                1023,
#                1099,
#                1110,
#                1149,
#                1274,
#                1490,
#                1558,
#                1642,
#                1681,
#                1713,
#                1722,
#                1751,
#                1800,
#                1814,
#                1823,
#                1835,
#                1890},
#               23: {32,
#                47,
#                49,
#                50,
#                53,
#                69,
#                70,
#                75,
#                78,
#                81,
#                83,
#                84,
#                103,
#                127,
#                153,
#                155,
#                160,
#                163,
#                171,
#                172,
#                174,
#                177,
#                185,
#                187,
#                189,
#                191,
#                194,
#                195,
#                202,
#                219,
#                221,
#                260,
#                265,
#                271,
#                283,
#                286,
#                290,
#                295,
#                301,
#                303,
#                305,
#                315,
#                352,
#                355,
#                357,
#                359,
#                364,
#                366,
#                371,
#                386,
#                399,
#                406,
#                412,
#                440,
#                474,
#                500,
#                504,
#                514,
#                516,
#                524,
#                532,
#                537,
#                541,
#                551,
#                570,
#                572,
#                575,
#                577,
#                581,
#                601,
#                606,
#                630,
#                631,
#                663,
#                667,
#                672,
#                676,
#                689,
#                699,
#                700,
#                710,
#                713,
#                752,
#                760,
#                763,
#                768,
#                771,
#                796,
#                839,
#                842,
#                863,
#                884,
#                894,
#                901,
#                908,
#                909,
#                924,
#                937,
#                976,
#                1016,
#                1018,
#                1076,
#                1090,
#                1105,
#                1109,
#                1121,
#                1129,
#                1134,
#                1136,
#                1178,
#                1194,
#                1221,
#                1244,
#                1247,
#                1262,
#                1273,
#                1288,
#                1295,
#                1322,
#                1325,
#                1326,
#                1328,
#                1346,
#                1367,
#                1371,
#                1374,
#                1393,
#                1405,
#                1409,
#                1416,
#                1418,
#                1439,
#                1443,
#                1444,
#                1455,
#                1459,
#                1471,
#                1485,
#                1493,
#                1498,
#                1511,
#                1513,
#                1526,
#                1535,
#                1545,
#                1560,
#                1632,
#                1676,
#                1695,
#                1721,
#                1726,
#                1749,
#                1823,
#                1828,
#                1830,
#                1848,
#                1857,
#                1861,
#                1865,
#                1866,
#                1869,
#                1883,
#                1899,
#                1908,
#                1918,
#                1937,
#                1948,
#                1965},
#               24: {37,
#                99,
#                145,
#                152,
#                156,
#                159,
#                319,
#                347,
#                359,
#                399,
#                406,
#                411,
#                424,
#                539,
#                593,
#                746,
#                900,
#                1011,
#                1068,
#                1181,
#                1399,
#                1486,
#                1506,
#                1508,
#                1542,
#                1585,
#                1609,
#                1678,
#                1756,
#                1914,
#                1957},
#               25: {44,
#                324,
#                360,
#                691,
#                903,
#                956,
#                960,
#                973,
#                1035,
#                1123,
#                1173,
#                1177,
#                1313,
#                1494,
#                1707,
#                1735,
#                1807,
#                1878,
#                1965},
#               26: {62, 239, 289, 475, 569, 626, 767, 1098, 1142, 1307},
#               27: {64,
#                376,
#                525,
#                608,
#                637,
#                644,
#                688,
#                769,
#                826,
#                829,
#                874,
#                893,
#                961,
#                980,
#                1006,
#                1026,
#                1183,
#                1254,
#                1977},
#               28: {64, 637, 826, 874, 980},
#               29: {74,
#                91,
#                182,
#                193,
#                354,
#                380,
#                495,
#                634,
#                652,
#                657,
#                728,
#                772,
#                891,
#                1049,
#                1179,
#                1253,
#                1283,
#                1383,
#                1397,
#                1406,
#                1489,
#                1608,
#                1824,
#                1841,
#                1843,
#                1880,
#                1923,
#                1958},
#               30: {88,
#                234,
#                352,
#                478,
#                501,
#                608,
#                899,
#                909,
#                940,
#                961,
#                966,
#                1026,
#                1078,
#                1217,
#                1242,
#                1256,
#                1361,
#                1565,
#                1977},
#               31: {114, 261, 438, 655, 678, 946, 1132, 1528, 1725},
#               32: {122,
#                132,
#                218,
#                318,
#                365,
#                379,
#                397,
#                415,
#                514,
#                550,
#                556,
#                612,
#                617,
#                624,
#                636,
#                697,
#                712,
#                748,
#                753,
#                770,
#                778,
#                792,
#                925,
#                934,
#                960,
#                990,
#                995,
#                1027,
#                1066,
#                1081,
#                1125,
#                1131,
#                1162,
#                1317,
#                1339,
#                1345,
#                1379,
#                1402,
#                1413,
#                1441,
#                1447,
#                1498,
#                1536,
#                1539,
#                1545,
#                1554,
#                1563,
#                1660,
#                1663,
#                1699,
#                1712,
#                1742,
#                1774,
#                1874,
#                1894,
#                1909},
#               33: {140, 223, 674, 727, 1407},
#               34: {141,
#                489,
#                633,
#                730,
#                1137,
#                1264,
#                1384,
#                1569,
#                1639,
#                1661,
#                1677,
#                1736,
#                1739,
#                1766,
#                1807},
#               35: {143,
#                402,
#                418,
#                472,
#                562,
#                565,
#                814,
#                853,
#                929,
#                962,
#                1088,
#                1227,
#                1305,
#                1500,
#                1523,
#                1891},
#               36: {143},
#               37: {143},
#               38: {157, 204, 396, 697, 831, 998, 1630},
#               39: {158,
#                196,
#                267,
#                465,
#                736,
#                876,
#                902,
#                938,
#                963,
#                1009,
#                1015,
#                1135,
#                1160,
#                1195,
#                1198,
#                1309,
#                1331,
#                1463,
#                1668,
#                1719,
#                1809,
#                1857},
#               40: {176,
#                209,
#                224,
#                708,
#                718,
#                956,
#                1008,
#                1197,
#                1613,
#                1698,
#                1767,
#                1825},
#               41: {181, 328, 953, 954},
#               42: {181, 953, 954},
#               43: {263,
#                265,
#                567,
#                787,
#                998,
#                1019,
#                1193,
#                1427,
#                1440,
#                1628,
#                1635,
#                1741,
#                1818,
#                1933},
#               44: {273,
#                308,
#                360,
#                405,
#                521,
#                566,
#                580,
#                585,
#                627,
#                646,
#                738,
#                793,
#                887,
#                969,
#                987,
#                1106,
#                1156,
#                1278,
#                1354,
#                1461,
#                1473,
#                1619,
#                1873},
#               45: {325, 1297},
#               46: {328},
#               47: {335, 947},
#               48: {338, 677, 680, 1167, 1662, 1706},
#               49: {343, 607, 681, 802},
#               50: {351, 493, 1042, 1112, 1222, 1949},
#               51: {367,
#                497,
#                613,
#                790,
#                1099,
#                1264,
#                1380,
#                1502,
#                1808,
#                1968,
#                1981},
#               52: {376},
#               53: {422},
#               54: {431,
#                663,
#                1141,
#                1279,
#                1410,
#                1500,
#                1526,
#                1634,
#                1645,
#                1676,
#                1847,
#                1876},
#               55: {431,
#                663,
#                1141,
#                1279,
#                1410,
#                1500,
#                1526,
#                1634,
#                1645,
#                1676,
#                1847,
#                1876},
#               56: {444,
#                501,
#                529,
#                769,
#                898,
#                940,
#                1183,
#                1254,
#                1256,
#                1285,
#                1529,
#                1620,
#                1727,
#                1771},
#               57: {525, 644, 688, 829, 1297, 1571, 1692},
#               58: {626},
#               59: {637, 1565},
#               60: {654, 808, 1110, 1175, 1328},
#               61: {710, 789, 875, 1209, 1357, 1466, 1607, 1688},
#               62: {883},
#               63: {883},
#               64: {893},
#               65: {893},
#               66: {920},
#               67: {1006},
#               68: {1023},
#               69: {1104},
#               70: {1242, 1956},
#               71: {1446},
#               72: {1529},
#               73: {1571},
#               74: {1636, 1845},
#               75: {1972}})}

# %%
import pandas as pd
from collections import defaultdict

# Carica il dataset Michelin dal file .tsv
dataset_path =  r"C:\Users\Utente\OneDrive - uniroma1.it\Esami\ADM\Homework 3\michelin_restaurants_data.tsv"
df = pd.read_csv(dataset_path, sep='\t')

# Aggiunge la colonna 'region' con valore di default "unknown" per ogni riga, in modo dinamico
df["region"] = ["unknown"] * len(df)
# Aggiunge un ID univoco
df["id"] = df.index

# Debug per verificare la presenza delle colonne
print("Colonne del DataFrame:", df.columns)
print("Esempio di righe:", df.head())

def build_inverted_index(df, field):
    inverted_index = defaultdict(list)
    for idx, row in df.iterrows():
        terms = str(row[field]).lower().split()
        for term in terms:
            inverted_index[term].append(row["id"])
    return dict(inverted_index)

# Creiamo gli indici invertiti per i campi specifici
restaurant_name_index = build_inverted_index(df, "restaurantName")
city_index = build_inverted_index(df, "city")
cuisine_type_index = build_inverted_index(df, "cuisineType")

def filter_by_price_range(df, min_price, max_price):
    price_levels = {"€": 1, "€€": 2, "€€€": 3, "€€€€": 4}
    min_level = price_levels.get(min_price, 1)
    max_level = price_levels.get(max_price, 4)
    return df[df["priceRange"].apply(lambda x: min_level <= price_levels.get(x, 0) <= max_level)]

def filter_by_region(df, regions):
    print("Debug - Esecuzione filter_by_region")  # Debug per sapere quando entriamo nella funzione
    print("Regioni richieste:", regions)         # Stampa le regioni che stiamo cercando
    print("Valori unici nella colonna 'region':", df["region"].unique())  # Controllo sui valori presenti

    regions = [region.lower() for region in regions]
    return df[df["region"].str.lower().isin(regions)]

def filter_by_credit_cards(df, accepted_cards):
    return df[df["creditCards"].apply(lambda x: any(card in str(x) for card in accepted_cards))]

def filter_by_services(df, required_services):
    return df[df["facilitiesServices"].apply(lambda x: all(service in str(x) for service in required_services))]

def advanced_search_2(df, queries=None, min_price=None, max_price=None, regions=None, accepted_cards=None, required_services=None):
    results = df
    if queries:
        if "restaurantName" in queries:
            name_terms = queries["restaurantName"].lower().split()
            name_matches = set()
            for term in name_terms:
                name_matches.update(restaurant_name_index.get(term, []))
            results = results[results["id"].isin(name_matches)]
        
        if "city" in queries:
            city_terms = queries["city"].lower().split()
            city_matches = set()
            for term in city_terms:
                city_matches.update(city_index.get(term, []))
            results = results[results["id"].isin(city_matches)]
        
        if "cuisineType" in queries:
            cuisine_terms = queries["cuisineType"].lower().split()
            cuisine_matches = set()
            for term in cuisine_terms:
                cuisine_matches.update(cuisine_type_index.get(term, []))
            results = results[results["id"].isin(cuisine_matches)]
    
    if min_price and max_price:
        results = filter_by_price_range(results, min_price, max_price)
    
    if regions:
        print("Debug - Chiamata a filter_by_region con:", regions)  # Debug per la funzione di filtro regione
        results = filter_by_region(results, regions)
    
    if accepted_cards:
        results = filter_by_credit_cards(results, accepted_cards)
    
    if required_services:
        results = filter_by_services(results, required_services)

    return results[["restaurantName", "address", "cuisineType", "priceRange", "website"]]

queries = {
    "restaurantName": "Al Camin",
    "city": "Cortina",
    "cuisineType": "Italian"
}
min_price = "€"
max_price = "€€€"
regions = ["known"]
accepted_cards = ["Visa", "MasterCard"]
required_services = ["Wi-Fi", "Terrace"]

results = advanced_search_2(
    df,
    queries=queries,
    min_price=min_price,
    max_price=max_price,
    regions=regions,
    accepted_cards=accepted_cards,
    required_services=required_services
)

print(results)
# Out:
# Colonne del DataFrame: Index(['restaurantName', 'address', 'city', 'postalCode', 'country',
#        'priceRange', 'cuisineType', 'description', 'facilitiesServices',
#        'creditCards', 'phoneNumber', 'website', 'region', 'id'],
#       dtype='object')
# Esempio di righe:       restaurantName                    address                    city  \
# 0              20Tre   via David Chiossone 20 r                   Genoa
# 1     Alessandro Feo        via Angelo Lista 24  Marina di Casal Velino
# 2  Ape Vino e Cucina      Piazza Risorgimento 3                    Alba
# 3         Charleston  via Generale Magliocco 19                 Palermo
# 4   Da Bob Cook Fish   largo Parsano vecchio 16                Sorrento
#
#    postalCode country priceRange                    cuisineType  \
# 0       16123   Italy         €€  Farm to table, Modern Cuisine
# 1       84040   Italy         €€             Campanian, Seafood
# 2       12051   Italy         €€      Piedmontese, Contemporary
# 3       90141   Italy       €€€€       Modern Cuisine, Creative
# 4       80067   Italy         €€                        Seafood
#
#                                          description  \
# 0  Situated in the heart of Genoa’s historic cent...
# 1  In a beautiful stone-vaulted building (an old ...
# 2  This attractive restaurant in the heart of Alb...
# 3  Before it became famous in Mondello, the renow...
# 4  Working in partnership with the nearby fishmon...
#
#                                   facilitiesServices  \
# 0                                   Air conditioning
# 1                                                NaN
# 2       Air conditioning, Terrace, Wheelchair access
# 3  Air conditioning, Counter dining, Terrace, Whe...
# 4                          Air conditioning, Terrace
#
#                                        creditCards        phoneNumber  \
# 0               Amex, Dinersclub, Mastercard, Visa   +39 010 247 6191
# 1               Amex, Dinersclub, Mastercard, Visa   +39 328 893 7083
# 2  Amex, Dinersclub, Maestrocard, Mastercard, Visa    +39 0173 363453
# 3                           Amex, Mastercard, Visa     +39 091 450171
# 4               Amex, Dinersclub, Mastercard, Visa  +39 081 1778 3873
#
#                                    website   region  id
# 0    https://www.ristorante20tregenova.it/  unknown   0
# 1  https://www.alessandrofeoristorante.it/  unknown   1
# 2          https://www.apewinebar.it/alba/  unknown   2
# 3              https://casacharleston.net/  unknown   3
# 4           https://www.dabobcookfish.com/  unknown   4
# Debug - Chiamata a filter_by_region con: unknown
# Debug - Esecuzione filter_by_region
# Regioni richieste: unknown
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Utente\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 100
#      97 accepted_cards = ["Visa", "MasterCard"]
#      98 required_services = ["Wi-Fi", "Terrace"]
# --> 100 results = advanced_search_2(
#     101     df,
#     102     queries=queries,
#     103     min_price=min_price,
#     104     max_price=max_price,
#     105     regions=regions,
#     106     accepted_cards=accepted_cards,
#     107     required_services=required_services
#     108 )
#     111 print(results)
#
# Cell In[5], line 79, in advanced_search_2(df, queries, min_price, max_price, regions, accepted_cards, required_services)
#      77 if regions:
#      78     print("Debug - Chiamata a filter_by_region con:", regions)  # Debug per la funzione di filtro regione
# ---> 79     results = filter_by_region(results, regions)
#      81 if accepted_cards:
#      82     results = filter_by_credit_cards(results, accepted_cards)
#
# Cell In[5], line 39, in filter_by_region(df, regions)
#      37 print("Debug - Esecuzione filter_by_region")  # Debug per sapere quando entriamo nella funzione
#      38 print("Regioni richieste:", regions)         # Stampa le regioni che stiamo cercando
# ---> 39 print("Valori unici nella colonna 'region':", df["region"].unique())  # Controllo sui valori presenti
#      41 regions = [region.lower() for region in regions]
#      42 return df[df["region"].str.lower().isin(regions)]
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'region'

# %%
len(df)
# Out:
# 1982
